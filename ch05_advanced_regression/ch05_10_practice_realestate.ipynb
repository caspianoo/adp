# %% [markdown]
# # Ch05-10: 실전: 부동산 가격 모델링

# %% [markdown]
# ## 학습 목표
#
# - 실전: 부동산 가격 모델링 이론
# - 실전: 부동산 가격 모델링 구현
# - 실전: 부동산 가격 모델링 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 공간 자기상관 + 비선형 효과를 고려한 해석 가능 모형 구축

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression, Ridge

data = fetch_california_housing()
X, y = data.data, data.target
names = data.feature_names

lr = LinearRegression()
ridge = Ridge(alpha=1.0)
print(f"OLS CV R²: {cross_val_score(lr, X, y, cv=5).mean():.3f}")
print(f"Ridge CV R²: {cross_val_score(ridge, X, y, cv=5).mean():.3f}")

ridge.fit(X, y)
for name, coef in sorted(zip(names, ridge.coef_), key=lambda x: abs(x[1]), reverse=True):
    print(f"  {name}: {coef:.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 부동산 가격 모델링의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 부동산 가격 모델링 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 부동산 가격 모델링 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 부동산 가격 모델링 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 부동산 가격 모델링을 적용하고 결과를 해석하세요.

# %%
# 실전: 부동산 가격 모델링 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
