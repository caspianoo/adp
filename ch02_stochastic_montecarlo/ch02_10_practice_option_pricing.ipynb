# %% [markdown]
# # Ch02-10: 실전: 금융 옵션 가격 결정

# %% [markdown]
# ## 학습 목표
#
# - Black-Scholes 모형의 MC 시뮬레이션
# - 경로 의존 옵션(아시안, 장벽)
# - 그리스 문자의 MC 추정

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 유럽형 콜옵션: $C = e^{-rT}E[\max(S_T - K, 0)]$
# 아시안 옵션: $C = e^{-rT}E[\max(\bar{S} - K, 0)]$, $\bar{S} = \frac{1}{n}\sum S_{t_i}$
# Delta: $\Delta = \frac{\partial C}{\partial S_0} \approx \frac{C(S_0+h) - C(S_0-h)}{2h}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

# 실전: 금융 옵션 가격 결정 기본 구현
print("=== 실전: 금융 옵션 가격 결정 ===")

# 유럽형 콜옵션 MC 가격 결정
S0, K, T, r, sigma = 100, 105, 1.0, 0.05, 0.2
N = 100000
np.random.seed(42)

Z = np.random.standard_normal(N)
ST = S0 * np.exp((r - 0.5*sigma**2)*T + sigma*np.sqrt(T)*Z)
payoff = np.maximum(ST - K, 0)
C_mc = np.exp(-r*T) * payoff.mean()
se = np.exp(-r*T) * payoff.std() / np.sqrt(N)

# Black-Scholes 해석해
from scipy.stats import norm
d1 = (np.log(S0/K) + (r + 0.5*sigma**2)*T) / (sigma*np.sqrt(T))
d2 = d1 - sigma*np.sqrt(T)
C_bs = S0*norm.cdf(d1) - K*np.exp(-r*T)*norm.cdf(d2)

print(f"MC 가격: {C_mc:.4f} ± {1.96*se:.4f}")
print(f"BS 가격: {C_bs:.4f}")
print(f"오차: {abs(C_mc - C_bs):.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 금융 옵션 가격 결정의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 금융 옵션 가격 결정 구현
import numpy as np
np.random.seed(42)

# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 실전: 금융 옵션 가격 결정에서 다양한 하이퍼파라미터/조건에 따른 성능을 비교 분석하세요.

# %%
# 실전: 금융 옵션 가격 결정 파라미터 분석
# TODO: 체계적 비교

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실전: 금융 옵션 가격 결정을 실전 문제에 적용하고 결과를 해석하세요.

# %%
# 실전: 금융 옵션 가격 결정 실전 적용
# TODO: 실제 데이터/문제에 적용

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 및 논문 참조
