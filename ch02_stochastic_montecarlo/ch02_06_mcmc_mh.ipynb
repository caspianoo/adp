# %% [markdown]
# # Ch02-06: MCMC: Metropolis-Hastings

# %% [markdown]
# ## 학습 목표
#
# - MH 알고리즘의 상세 균형 조건
# - 수렴 진단: trace plot, autocorrelation, R-hat
# - 제안 분포 조율과 수용률

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# MH 수용 확률: $\alpha(x, y) = \min\left(1, \frac{\pi(y) q(y|x)}{\pi(x) q(x|y)}\right)$
# 상세 균형: $\pi(x)P(x,y) = \pi(y)P(y,x)$ → $\pi$가 정상 분포
# 최적 수용률: 약 0.234 (고차원), 0.44 (1차원)

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

# MCMC: Metropolis-Hastings 기본 구현
print("=== MCMC: Metropolis-Hastings ===")

# Metropolis-Hastings: 이변량 정규 분포에서 샘플링
target_mean = np.array([2, 3])
target_cov = np.array([[1, 0.8], [0.8, 1]])
target_cov_inv = np.linalg.inv(target_cov)

def log_target(x):
    d = x - target_mean
    return -0.5 * d @ target_cov_inv @ d

n_samples = 20000
samples = np.zeros((n_samples, 2))
x = np.zeros(2)
accepted = 0

for i in range(n_samples):
    proposal = x + np.random.normal(0, 0.5, 2)
    log_alpha = log_target(proposal) - log_target(x)
    if np.log(np.random.rand()) < log_alpha:
        x = proposal
        accepted += 1
    samples[i] = x

burn_in = 2000
print(f"수용률: {accepted/n_samples:.3f}")
print(f"추정 평균: {samples[burn_in:].mean(axis=0).round(3)}")
print(f"추정 공분산:\n{np.cov(samples[burn_in:].T).round(3)}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# MCMC: Metropolis-Hastings의 핵심 알고리즘을 직접 구현하세요.

# %%
# MCMC: Metropolis-Hastings 구현
import numpy as np
np.random.seed(42)

# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# MCMC: Metropolis-Hastings에서 다양한 하이퍼파라미터/조건에 따른 성능을 비교 분석하세요.

# %%
# MCMC: Metropolis-Hastings 파라미터 분석
# TODO: 체계적 비교

# %% [markdown]
# ### 문제 3 [★★★]
#
# MCMC: Metropolis-Hastings을 실전 문제에 적용하고 결과를 해석하세요.

# %%
# MCMC: Metropolis-Hastings 실전 적용
# TODO: 실제 데이터/문제에 적용

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 및 논문 참조
