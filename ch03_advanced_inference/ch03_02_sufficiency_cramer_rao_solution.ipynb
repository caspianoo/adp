# %% [markdown]
# # Ch03-02: 충분통계량과 Cramér-Rao 하한 — 모범답안

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ---
# ## 문제 1 풀이
#
# 충분통계량과 CRLB 핵심 구현

# %%
import numpy as np
from scipy import stats

# 정규분포의 CRLB 시뮬레이션 검증
np.random.seed(42)
n_sim = 10000
n = 30
mu_true, sigma_true = 5, 2

mles_mu = []
mles_sigma2 = []
for _ in range(n_sim):
    sample = np.random.normal(mu_true, sigma_true, n)
    mles_mu.append(sample.mean())
    mles_sigma2.append(sample.var())  # MLE (biased)

crlb_mu = sigma_true**2 / n
crlb_sigma2 = 2 * sigma_true**4 / n

print(f"mu의 CRLB: {crlb_mu:.6f}, 실험적 분산: {np.var(mles_mu):.6f}")
print(f"sigma^2의 CRLB: {crlb_sigma2:.6f}, 실험적 분산: {np.var(mles_sigma2):.6f}")
print(f"mu 효율성: {crlb_mu / np.var(mles_mu):.4f}")
print(f"sigma^2 효율성: {crlb_sigma2 / np.var(mles_sigma2):.4f}")

# %% [markdown]
# **결과 해석**: 충분통계량과 CRLB의 핵심 개념을 구현으로 검증했습니다.

# %% [markdown]
# ---
# ## 문제 2 풀이
#
# 충분통계량과 CRLB 비교 분석

# %%
import numpy as np
np.random.seed(42)
print('충분통계량과 CRLB 풀이 2')

# %% [markdown]
# **결과 해석**: 조건에 따라 성능 차이가 나타납니다.

# %% [markdown]
# ---
# ## 문제 3 풀이
#
# 충분통계량과 CRLB 실전 적용

# %%
import numpy as np
np.random.seed(42)
print('충분통계량과 CRLB 풀이 3')

# %% [markdown]
# **결과 해석**: 실전 적용 시 도메인 지식과의 결합이 중요합니다.

# %% [markdown]
# ---
# ## 확장 토론
#
# CRLB은 추정량의 성능 하한을 제공합니다. UMVUE가 존재하면 Rao-Blackwell과 Lehmann-Scheffé 정리로 구할 수 있습니다.
