# %% [markdown]
# # Ch07-01: 베이즈 정리와 사전 분포

# %% [markdown]
# ## 학습 목표
#
# - 베이즈 정리와 사전 분포 이론
# - 베이즈 정리와 사전 분포 구현
# - 베이즈 정리와 사전 분포 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $p(\theta|y) \propto p(y|\theta)p(\theta)$. Jeffrey's prior: $p(\theta) \propto \sqrt{I(\theta)}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
x = np.linspace(0, 1, 200)
# Beta prior + Binomial likelihood
n_obs, k = 20, 14
for a, b, name in [(1,1,'균등'), (0.5,0.5,"Jeffrey's"), (2,5,'정보적')]:
    prior = stats.beta.pdf(x, a, b)
    posterior = stats.beta.pdf(x, a+k, b+n_obs-k)
    plt.plot(x, posterior, label=f'사후({name})')
plt.axvline(k/n_obs, color='gray', linestyle='--', label='MLE')
plt.legend(); plt.title(f'관측: {k}/{n_obs}')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 베이즈 정리와 사전 분포의 핵심 알고리즘을 직접 구현하세요.

# %%
# 베이즈 정리와 사전 분포 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 베이즈 정리와 사전 분포 방법론의 성능을 비교 분석하세요.

# %%
# 베이즈 정리와 사전 분포 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 베이즈 정리와 사전 분포을 적용하고 결과를 해석하세요.

# %%
# 베이즈 정리와 사전 분포 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
