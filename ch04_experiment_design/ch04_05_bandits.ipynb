# %% [markdown]
# # Ch04-05: 멀티암 밴딧과 적응적 실험

# %% [markdown]
# ## 학습 목표
#
# - 멀티암 밴딧과 적응적 실험 이론 이해
# - 멀티암 밴딧과 적응적 실험 구현
# - 멀티암 밴딧과 적응적 실험 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# Thompson Sampling: $\theta_k \sim \text{Beta}(\alpha_k, \beta_k)$에서 샘플링 후 최대 팔 선택. UCB: $a_t = \arg\max_k \hat\mu_k + c\sqrt{\frac{\ln t}{N_k(t)}}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt

class ThompsonSampling:
    def __init__(self, n_arms):
        self.alpha = np.ones(n_arms)
        self.beta = np.ones(n_arms)

    def select(self):
        samples = [np.random.beta(a, b) for a, b in zip(self.alpha, self.beta)]
        return np.argmax(samples)

    def update(self, arm, reward):
        if reward: self.alpha[arm] += 1
        else: self.beta[arm] += 1

np.random.seed(42)
true_probs = [0.1, 0.3, 0.5, 0.2]
n_rounds = 2000
ts = ThompsonSampling(4)
rewards_hist, arms_hist = [], []

for t in range(n_rounds):
    arm = ts.select()
    reward = np.random.binomial(1, true_probs[arm])
    ts.update(arm, reward)
    rewards_hist.append(reward)
    arms_hist.append(arm)

cumulative_regret = np.cumsum([max(true_probs) - true_probs[a] for a in arms_hist])
plt.figure(figsize=(10, 5))
plt.plot(cumulative_regret)
plt.xlabel('라운드'); plt.ylabel('누적 후회')
plt.title('Thompson Sampling 누적 후회')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 멀티암 밴딧과 적응적 실험의 핵심 알고리즘을 직접 구현하세요.

# %%
# 멀티암 밴딧과 적응적 실험 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 멀티암 밴딧과 적응적 실험 방법론의 성능을 비교 분석하세요.

# %%
# 멀티암 밴딧과 적응적 실험 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 멀티암 밴딧과 적응적 실험을 적용하고 결과를 해석하세요.

# %%
# 멀티암 밴딧과 적응적 실험 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
