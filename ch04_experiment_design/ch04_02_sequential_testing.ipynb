# %% [markdown]
# # Ch04-02: 순차 검정과 조기 중단

# %% [markdown]
# ## 학습 목표
#
# - 순차 검정과 조기 중단 이론 이해
# - 순차 검정과 조기 중단 구현
# - 순차 검정과 조기 중단 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# SPRT: $\Lambda_n = \prod \frac{f(x_i|\theta_1)}{f(x_i|\theta_0)}$. 중단 규칙: $A \leq \Lambda_n \leq B$이면 계속, $A = \beta/(1-\alpha)$, $B = (1-\beta)/\alpha$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt

def sprt(data, mu0, mu1, sigma, alpha=0.05, beta=0.1):
    A = beta / (1 - alpha)
    B = (1 - beta) / alpha
    log_A, log_B = np.log(A), np.log(B)

    log_lr = 0
    history = [0]
    for i, x in enumerate(data):
        log_lr += (mu1 - mu0) / sigma**2 * (x - (mu0 + mu1) / 2)
        history.append(log_lr)
        if log_lr >= log_B: return 'reject H0', i+1, history
        if log_lr <= log_A: return 'accept H0', i+1, history
    return 'no decision', len(data), history

np.random.seed(42)
data = np.random.normal(0.3, 1, 500)
decision, n_obs, hist = sprt(data, mu0=0, mu1=0.5, sigma=1)
print(f"SPRT: {decision} at n={n_obs}")

plt.figure(figsize=(12, 5))
plt.plot(hist)
plt.axhline(np.log((1-0.1)/0.05), color='red', linestyle='--', label='Reject boundary')
plt.axhline(np.log(0.1/(1-0.05)), color='green', linestyle='--', label='Accept boundary')
plt.xlabel('관측 수'); plt.ylabel('Log likelihood ratio')
plt.title('SPRT'); plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 순차 검정과 조기 중단의 핵심 알고리즘을 직접 구현하세요.

# %%
# 순차 검정과 조기 중단 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 순차 검정과 조기 중단 방법론의 성능을 비교 분석하세요.

# %%
# 순차 검정과 조기 중단 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 순차 검정과 조기 중단을 적용하고 결과를 해석하세요.

# %%
# 순차 검정과 조기 중단 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
