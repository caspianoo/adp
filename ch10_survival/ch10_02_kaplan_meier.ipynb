# %% [markdown]
# # Ch10-02: Kaplan-Meier와 로그순위 검정

# %% [markdown]
# ## 학습 목표
#
# - Kaplan-Meier와 로그순위 검정 이론
# - Kaplan-Meier와 로그순위 검정 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $\hat{S}(t) = \prod_{t_i \leq t}\frac{n_i - d_i}{n_i}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
T1 = np.random.exponential(5, 100); C1 = np.random.exponential(8, 100)
T2 = np.random.exponential(3, 100); C2 = np.random.exponential(8, 100)
def kaplan_meier(T, C):
    obs = np.minimum(T, C); event = (T <= C).astype(int)
    times = np.sort(np.unique(obs[event==1]))
    S = [1.0]; surv = 1.0
    for t in times:
        d = np.sum((obs == t) & (event == 1))
        n = np.sum(obs >= t)
        surv *= (1 - d/n); S.append(surv)
    return np.concatenate([[0], times]), S
t1, s1 = kaplan_meier(T1, C1); t2, s2 = kaplan_meier(T2, C2)
plt.figure(figsize=(10, 6))
plt.step(t1, s1, label='Group 1'); plt.step(t2, s2, label='Group 2')
plt.xlabel('Time'); plt.ylabel('S(t)'); plt.legend(); plt.title('Kaplan-Meier')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# Kaplan-Meier와 로그순위 검정의 핵심 알고리즘을 직접 구현하세요.

# %%
# Kaplan-Meier와 로그순위 검정 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 Kaplan-Meier와 로그순위 검정 방법론의 성능을 비교 분석하세요.

# %%
# Kaplan-Meier와 로그순위 검정 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 Kaplan-Meier와 로그순위 검정을 적용하고 결과를 해석하세요.

# %%
# Kaplan-Meier와 로그순위 검정 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
