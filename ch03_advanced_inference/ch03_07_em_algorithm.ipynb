# %% [markdown]
# # Ch03-07: EM 알고리즘의 이론과 응용

# %% [markdown]
# ## 학습 목표
#
# - EM 알고리즘의 이론과 응용의 핵심 이론 이해
# - EM 알고리즘의 이론과 응용의 실전 구현
# - EM 알고리즘의 이론과 응용 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# E-step: $Q(\theta|\theta^{(t)}) = E_{Z|X,\theta^{(t)}}[\log L(\theta; X, Z)]$. M-step: $\theta^{(t+1)} = \arg\max_\theta Q(\theta|\theta^{(t)})$. 수렴: $\ell(\theta^{(t+1)}) \geq \ell(\theta^{(t)})$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== EM 알고리즘의 이론과 응용 ===")

# EM 알고리즘: 가우시안 혼합 모형
from sklearn.datasets import make_blobs

X, y_true = make_blobs(n_samples=300, centers=3, cluster_std=1.0, random_state=42)

# EM 직접 구현 (1D 간소화)
data = X[:, 0]
K = 3
n = len(data)

# 초기화
mu = np.array([-3, 0, 3], dtype=float)
sigma = np.ones(K)
pi_k = np.ones(K) / K

for iteration in range(50):
    # E-step: 책임도 계산
    gamma = np.zeros((n, K))
    for k in range(K):
        gamma[:, k] = pi_k[k] * stats.norm.pdf(data, mu[k], sigma[k])
    gamma /= gamma.sum(axis=1, keepdims=True)

    # M-step
    N_k = gamma.sum(axis=0)
    mu = (gamma * data[:, None]).sum(axis=0) / N_k
    sigma = np.sqrt((gamma * (data[:, None] - mu)**2).sum(axis=0) / N_k)
    pi_k = N_k / n

print(f"추정된 평균: {np.sort(mu).round(3)}")
print(f"혼합 비율: {pi_k.round(3)}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# EM 알고리즘의 이론과 응용의 핵심 알고리즘을 직접 구현하세요.

# %%
# EM 알고리즘의 이론과 응용 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 EM 알고리즘의 이론과 응용 방법론의 성능을 비교 분석하세요.

# %%
# EM 알고리즘의 이론과 응용 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 EM 알고리즘의 이론과 응용을 적용하고 결과를 해석하세요.

# %%
# EM 알고리즘의 이론과 응용 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
