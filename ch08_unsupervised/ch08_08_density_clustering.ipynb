# %% [markdown]
# # Ch08-08: 밀도 기반 클러스터링

# %% [markdown]
# ## 학습 목표
#
# - 밀도 기반 클러스터링 이론
# - 밀도 기반 클러스터링 구현
# - 밀도 기반 클러스터링 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# DBSCAN: $\epsilon$-이웃에 minPts 이상이면 core point. HDBSCAN: 다양한 $\epsilon$에 대해 안정적인 클러스터 추출

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons, make_blobs
X1, _ = make_moons(200, noise=0.1, random_state=42)
X2 = np.random.uniform(-2, 3, (50, 2))
X = np.vstack([X1, X2])
db = DBSCAN(eps=0.3, min_samples=5).fit(X)
plt.figure(figsize=(8, 6))
plt.scatter(X[:,0], X[:,1], c=db.labels_, cmap='viridis', s=20)
plt.title(f'DBSCAN: {len(set(db.labels_))-1} clusters, {(db.labels_==-1).sum()} noise')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 밀도 기반 클러스터링의 핵심 알고리즘을 직접 구현하세요.

# %%
# 밀도 기반 클러스터링 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 밀도 기반 클러스터링 방법론의 성능을 비교 분석하세요.

# %%
# 밀도 기반 클러스터링 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 밀도 기반 클러스터링을 적용하고 결과를 해석하세요.

# %%
# 밀도 기반 클러스터링 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
