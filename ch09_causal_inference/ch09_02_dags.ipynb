# %% [markdown]
# # Ch09-02: DAG와 do-계산

# %% [markdown]
# ## 학습 목표
#
# - DAG와 do-계산 이론
# - DAG와 do-계산 구현
# - DAG와 do-계산 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# d-분리: $X \perp Y | Z$이면 $Z$가 $X, Y$ 사이의 모든 경로를 차단. 백도어 기준: $Z$가 $X \to Y$의 모든 백도어 경로를 차단

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
np.random.seed(42)
n = 2000
# X -> Y, X <- U -> Y (교란)
U = np.random.normal(0, 1, n)
X = 0.5*U + np.random.normal(0, 1, n)
Y = 2*X + 1.5*U + np.random.normal(0, 1, n)
# 나이브 회귀 (편향)
from numpy.linalg import lstsq
beta_naive = lstsq(np.column_stack([np.ones(n), X]), Y, rcond=None)[0][1]
# U 통제 (백도어 조정)
beta_adj = lstsq(np.column_stack([np.ones(n), X, U]), Y, rcond=None)[0][1]
print(f"나이브: {beta_naive:.3f} (참=2, 편향)")
print(f"U 조정: {beta_adj:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# DAG와 do-계산의 핵심 알고리즘을 직접 구현하세요.

# %%
# DAG와 do-계산 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 DAG와 do-계산 방법론의 성능을 비교 분석하세요.

# %%
# DAG와 do-계산 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 DAG와 do-계산을 적용하고 결과를 해석하세요.

# %%
# DAG와 do-계산 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
