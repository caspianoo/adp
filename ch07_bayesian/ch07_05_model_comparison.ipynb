# %% [markdown]
# # Ch07-05: 베이지안 모형 비교

# %% [markdown]
# ## 학습 목표
#
# - 베이지안 모형 비교 이론
# - 베이지안 모형 비교 구현
# - 베이지안 모형 비교 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# WAIC: $\widehat{elpd} = \sum \log \bar{p}(y_i) - \sum p_{\text{WAIC},i}$. LOO-CV: Pareto smoothed importance sampling

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
print("=== 베이지안 모형 비교 ===")
print("WAIC = -2(lppd - p_waic)")
print("lppd = sum(log(mean(p(y_i|theta_s))))")
print("p_waic = sum(var(log p(y_i|theta_s)))")
print("\nWAIC이 낮을수록 좋은 모형")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 베이지안 모형 비교의 핵심 알고리즘을 직접 구현하세요.

# %%
# 베이지안 모형 비교 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 베이지안 모형 비교 방법론의 성능을 비교 분석하세요.

# %%
# 베이지안 모형 비교 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 베이지안 모형 비교을 적용하고 결과를 해석하세요.

# %%
# 베이지안 모형 비교 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
