# %% [markdown]
# # Ch07-09: 베이지안 비모수 (DP Mixture)

# %% [markdown]
# ## 학습 목표
#
# - 베이지안 비모수 (DP Mixture) 이론
# - 베이지안 비모수 (DP Mixture) 구현
# - 베이지안 비모수 (DP Mixture) 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# DP: $G \sim DP(\alpha, G_0)$. 스틱 브레이킹: $\pi_k = V_k\prod_{j<k}(1-V_j)$, $V_k \sim \text{Beta}(1, \alpha)$. CRP: $P(\text{new table}) = \frac{\alpha}{n-1+\alpha}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
# 스틱 브레이킹
def stick_breaking(alpha, K):
    betas = np.random.beta(1, alpha, K)
    pis = np.zeros(K)
    pis[0] = betas[0]
    for k in range(1, K):
        pis[k] = betas[k] * np.prod(1 - betas[:k])
    return pis

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, alpha in zip(axes, [0.1, 1.0, 10.0]):
    pis = stick_breaking(alpha, 20)
    ax.bar(range(20), pis)
    ax.set_title(f'α = {alpha}, 유효 클러스터: {(pis > 0.01).sum()}')
plt.suptitle('디리클레 과정: 스틱 브레이킹')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 베이지안 비모수 (DP Mixture)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 베이지안 비모수 (DP Mixture) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 베이지안 비모수 (DP Mixture) 방법론의 성능을 비교 분석하세요.

# %%
# 베이지안 비모수 (DP Mixture) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 베이지안 비모수 (DP Mixture)을 적용하고 결과를 해석하세요.

# %%
# 베이지안 비모수 (DP Mixture) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
