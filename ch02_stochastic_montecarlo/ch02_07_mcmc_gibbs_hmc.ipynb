# %% [markdown]
# # Ch02-07: 깁스 샘플링과 해밀토니안 MC

# %% [markdown]
# ## 학습 목표
#
# - 조건부 분포 기반 깁스 샘플링
# - 해밀턴 역학과 HMC
# - NUTS(No-U-Turn Sampler)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 깁스: $x_j^{(t+1)} \sim p(x_j | x_{-j}^{(t)})$ 각 성분 순차 업데이트
# HMC: 해밀토니안 $H(q,p) = U(q) + K(p)$, $U(q) = -\log\pi(q)$
# Leapfrog 적분: $p_{t+\epsilon/2} = p_t - \frac{\epsilon}{2}\nabla U(q_t)$, $q_{t+\epsilon} = q_t + \epsilon p_{t+\epsilon/2}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

# 깁스 샘플링과 해밀토니안 MC 기본 구현
print("=== 깁스 샘플링과 해밀토니안 MC ===")

# 깁스 샘플링: 이변량 정규
rho = 0.8
n_samples = 10000
samples = np.zeros((n_samples, 2))
x, y = 0.0, 0.0

for i in range(n_samples):
    x = np.random.normal(rho * y, np.sqrt(1 - rho**2))
    y = np.random.normal(rho * x, np.sqrt(1 - rho**2))
    samples[i] = [x, y]

print(f"상관계수 추정: {np.corrcoef(samples[1000:,0], samples[1000:,1])[0,1]:.3f} (참: {rho})")

plt.figure(figsize=(8, 8))
plt.scatter(samples[1000:,0], samples[1000:,1], alpha=0.1, s=1)
plt.title(f'깁스 샘플링 (ρ={rho})')
plt.xlabel('X'); plt.ylabel('Y')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 깁스 샘플링과 해밀토니안 MC의 핵심 알고리즘을 직접 구현하세요.

# %%
# 깁스 샘플링과 해밀토니안 MC 구현
import numpy as np
np.random.seed(42)

# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 깁스 샘플링과 해밀토니안 MC에서 다양한 하이퍼파라미터/조건에 따른 성능을 비교 분석하세요.

# %%
# 깁스 샘플링과 해밀토니안 MC 파라미터 분석
# TODO: 체계적 비교

# %% [markdown]
# ### 문제 3 [★★★]
#
# 깁스 샘플링과 해밀토니안 MC을 실전 문제에 적용하고 결과를 해석하세요.

# %%
# 깁스 샘플링과 해밀토니안 MC 실전 적용
# TODO: 실제 데이터/문제에 적용

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 및 논문 참조
