# %% [markdown]
# # Ch04-04: 다변량 실험 설계

# %% [markdown]
# ## 학습 목표
#
# - 다변량 실험 설계 이론 이해
# - 다변량 실험 설계 구현
# - 다변량 실험 설계 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $2^k$ 요인 설계: $Y = \mu + \sum \alpha_i x_i + \sum \beta_{ij} x_i x_j + \epsilon$. 교호작용: $\beta_{ij} \neq 0$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from itertools import product

# 2^3 요인 설계
factors = list(product([-1, 1], repeat=3))
X = np.array(factors)
labels = ['A', 'B', 'C']

# 반응 = 5 + 2*A + 3*B - 1*C + 1.5*AB + noise
np.random.seed(42)
n_rep = 5
Y_all = []
for combo in X:
    a, b, c = combo
    y = 5 + 2*a + 3*b - 1*c + 1.5*a*b + np.random.normal(0, 0.5, n_rep)
    Y_all.append(y)

Y_mean = np.array([y.mean() for y in Y_all])

# 효과 추정
effects = {}
for i, name in enumerate(labels):
    effects[name] = (Y_mean[X[:, i]==1].mean() - Y_mean[X[:, i]==-1].mean())
effects['AB'] = (Y_mean[(X[:,0]*X[:,1])==1].mean() - Y_mean[(X[:,0]*X[:,1])==-1].mean())
for k, v in effects.items(): print(f"효과 {k}: {v:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 다변량 실험 설계의 핵심 알고리즘을 직접 구현하세요.

# %%
# 다변량 실험 설계 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 다변량 실험 설계 방법론의 성능을 비교 분석하세요.

# %%
# 다변량 실험 설계 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 다변량 실험 설계을 적용하고 결과를 해석하세요.

# %%
# 다변량 실험 설계 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
