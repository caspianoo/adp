# %% [markdown]
# # Ch09-06: 도구 변수법 (IV)

# %% [markdown]
# ## 학습 목표
#
# - 도구 변수법 (IV) 이론
# - 도구 변수법 (IV) 구현
# - 도구 변수법 (IV) 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# LATE: $\tau_{LATE} = \frac{E[Y|Z=1]-E[Y|Z=0]}{E[D|Z=1]-E[D|Z=0]}$ (Wald 추정량)

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
np.random.seed(42)
n = 2000
Z = np.random.binomial(1, 0.5, n)  # 도구변수
U = np.random.normal(0, 1, n)
D = (0.3*Z + 0.5*U + np.random.normal(0, 0.5, n) > 0).astype(int)
Y = 2*D + 1.5*U + np.random.normal(0, 1, n)
# Wald 추정
wald = (Y[Z==1].mean()-Y[Z==0].mean()) / (D[Z==1].mean()-D[Z==0].mean())
print(f"OLS: {np.polyfit(D, Y, 1)[0]:.3f} (편향)")
print(f"Wald: {wald:.3f} (참: 2)")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 도구 변수법 (IV)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 도구 변수법 (IV) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 도구 변수법 (IV) 방법론의 성능을 비교 분석하세요.

# %%
# 도구 변수법 (IV) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 도구 변수법 (IV)을 적용하고 결과를 해석하세요.

# %%
# 도구 변수법 (IV) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
