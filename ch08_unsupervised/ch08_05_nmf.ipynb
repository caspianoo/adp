# %% [markdown]
# # Ch08-05: 비음수 행렬 분해 (NMF)

# %% [markdown]
# ## 학습 목표
#
# - 비음수 행렬 분해 (NMF) 이론
# - 비음수 행렬 분해 (NMF) 구현
# - 비음수 행렬 분해 (NMF) 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $\mathbf{X} \approx \mathbf{WH}$, $W \geq 0, H \geq 0$. 곱셈 업데이트: $H \leftarrow H \circ \frac{W^TX}{W^TWH}$, $W \leftarrow W \circ \frac{XH^T}{WHH^T}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.decomposition import NMF
np.random.seed(42)
# 합성 비음수 데이터
W_true = np.random.exponential(1, (100, 3))
H_true = np.random.exponential(1, (3, 50))
X = W_true @ H_true + 0.5*np.random.exponential(0.1, (100, 50))
nmf = NMF(n_components=3, init='random', random_state=42, max_iter=500)
W = nmf.fit_transform(X)
H = nmf.components_
print(f"재구성 오차: {np.linalg.norm(X - W@H) / np.linalg.norm(X):.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 비음수 행렬 분해 (NMF)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 비음수 행렬 분해 (NMF) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 비음수 행렬 분해 (NMF) 방법론의 성능을 비교 분석하세요.

# %%
# 비음수 행렬 분해 (NMF) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 비음수 행렬 분해 (NMF)을 적용하고 결과를 해석하세요.

# %%
# 비음수 행렬 분해 (NMF) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
