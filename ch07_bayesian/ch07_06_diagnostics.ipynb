# %% [markdown]
# # Ch07-06: 사후 예측 검정과 모형 진단

# %% [markdown]
# ## 학습 목표
#
# - 사후 예측 검정과 모형 진단 이론
# - 사후 예측 검정과 모형 진단 구현
# - 사후 예측 검정과 모형 진단 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 사후 예측: $y^{rep} \sim p(y^{rep}|y) = \int p(y^{rep}|\theta)p(\theta|y)d\theta$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
data = np.random.normal(5, 2, 100)
# 사후 예측 시뮬레이션 (정규-정규)
n_post = 1000
mu_post = data.mean()
sigma_post = 2 / np.sqrt(len(data))
y_rep = np.array([np.random.normal(np.random.normal(mu_post, sigma_post), 2, len(data)) for _ in range(n_post)])

plt.figure(figsize=(10, 6))
plt.hist(data, bins=20, density=True, alpha=0.5, label='관측')
for i in range(50):
    plt.hist(y_rep[i], bins=20, density=True, alpha=0.02, color='blue')
plt.title('사후 예측 검정')
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 사후 예측 검정과 모형 진단의 핵심 알고리즘을 직접 구현하세요.

# %%
# 사후 예측 검정과 모형 진단 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 사후 예측 검정과 모형 진단 방법론의 성능을 비교 분석하세요.

# %%
# 사후 예측 검정과 모형 진단 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 사후 예측 검정과 모형 진단을 적용하고 결과를 해석하세요.

# %%
# 사후 예측 검정과 모형 진단 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
