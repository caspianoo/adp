# %% [markdown]
# # Ch05-01: 일반화 선형 모형 (GLM)

# %% [markdown]
# ## 학습 목표
#
# - 일반화 선형 모형 (GLM) 이론
# - 일반화 선형 모형 (GLM) 구현
# - 일반화 선형 모형 (GLM) 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# GLM: $g(E[Y]) = \mathbf{X}\boldsymbol\beta$. 지수 족: $f(y|\theta) = h(y)\exp(\eta(\theta)T(y) - A(\theta))$. 편차: $D = 2\sum[y_i\hat\theta_i - b(\hat\theta_i)] - [y_i\tilde\theta_i - b(\tilde\theta_i)]$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import statsmodels.api as sm
np.random.seed(42)
n = 500
X = np.random.normal(0, 1, (n, 3))
eta = 0.5 + X @ np.array([1, -0.5, 0.3])
# 포아송 GLM
mu = np.exp(eta)
y = np.random.poisson(mu)
X_const = sm.add_constant(X)
model = sm.GLM(y, X_const, family=sm.families.Poisson())
result = model.fit()
print(result.summary().tables[1])

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 일반화 선형 모형 (GLM)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 일반화 선형 모형 (GLM) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 일반화 선형 모형 (GLM) 방법론의 성능을 비교 분석하세요.

# %%
# 일반화 선형 모형 (GLM) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 일반화 선형 모형 (GLM)을 적용하고 결과를 해석하세요.

# %%
# 일반화 선형 모형 (GLM) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
