# %% [markdown]
# # Ch08-02: 커널 PCA와 비선형 확장

# %% [markdown]
# ## 학습 목표
#
# - 커널 PCA와 비선형 확장 이론
# - 커널 PCA와 비선형 확장 구현
# - 커널 PCA와 비선형 확장 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 커널 트릭: $K_{ij} = k(x_i, x_j) = \phi(x_i)^T\phi(x_j)$. 중심화: $\tilde{K} = K - 1_nK - K1_n + 1_nK1_n$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.decomposition import KernelPCA
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=400, factor=0.3, noise=0.05, random_state=42)
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].scatter(X[:,0], X[:,1], c=y, cmap='coolwarm', s=10)
axes[0].set_title('원본')
for ax, kernel in zip(axes[1:], ['linear', 'rbf']):
    kpca = KernelPCA(n_components=2, kernel=kernel, gamma=10)
    X_t = kpca.fit_transform(X)
    ax.scatter(X_t[:,0], X_t[:,1], c=y, cmap='coolwarm', s=10)
    ax.set_title(f'Kernel PCA ({kernel})')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 커널 PCA와 비선형 확장의 핵심 알고리즘을 직접 구현하세요.

# %%
# 커널 PCA와 비선형 확장 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 커널 PCA와 비선형 확장 방법론의 성능을 비교 분석하세요.

# %%
# 커널 PCA와 비선형 확장 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 커널 PCA와 비선형 확장을 적용하고 결과를 해석하세요.

# %%
# 커널 PCA와 비선형 확장 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
