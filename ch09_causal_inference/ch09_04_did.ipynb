# %% [markdown]
# # Ch09-04: 이중 차분법 (DiD)

# %% [markdown]
# ## 학습 목표
#
# - 이중 차분법 (DiD) 이론
# - 이중 차분법 (DiD) 구현
# - 이중 차분법 (DiD) 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $\hat\tau_{DiD} = (\bar{Y}_{T,post} - \bar{Y}_{T,pre}) - (\bar{Y}_{C,post} - \bar{Y}_{C,pre})$. 핵심 가정: 평행 추세

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
n = 200; T = 10; treatment_time = 5; tau = 3
data_control = np.cumsum(np.random.normal(0.5, 1, T)) + np.random.normal(0, 0.5, (n, T))
data_treated = np.cumsum(np.random.normal(0.5, 1, T)) + np.random.normal(0, 0.5, (n, T))
data_treated[:, treatment_time:] += tau

pre_diff = data_treated[:, :treatment_time].mean() - data_control[:, :treatment_time].mean()
post_diff = data_treated[:, treatment_time:].mean() - data_control[:, treatment_time:].mean()
did = post_diff - pre_diff
print(f"DiD 추정: {did:.3f} (참: {tau})")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 이중 차분법 (DiD)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 이중 차분법 (DiD) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 이중 차분법 (DiD) 방법론의 성능을 비교 분석하세요.

# %%
# 이중 차분법 (DiD) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 이중 차분법 (DiD)을 적용하고 결과를 해석하세요.

# %%
# 이중 차분법 (DiD) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
