# %% [markdown]
# # Ch12-01: 공간 자기상관과 Moran's I

# %% [markdown]
# ## 학습 목표
#
# - 공간 자기상관과 Moran's I 이론
# - 공간 자기상관과 Moran's I 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $I = \frac{n}{\sum w_{ij}}\frac{\sum w_{ij}(x_i-\bar{x})(x_j-\bar{x})}{\sum(x_i-\bar{x})^2}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

import numpy as np
np.random.seed(42)
n = 100
coords = np.random.uniform(0, 10, (n, 2))
from scipy.spatial.distance import cdist
D = cdist(coords, coords)
W = (D < 2).astype(float); np.fill_diagonal(W, 0)
W = W / W.sum(axis=1, keepdims=True)
x = coords[:,0] + np.random.normal(0, 1, n)  # 공간 패턴
xc = x - x.mean()
I = (n / W.sum()) * (xc @ W @ xc) / (xc @ xc)
print(f"Moran's I: {I:.4f} (양의 자기상관)")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 공간 자기상관과 Moran's I의 핵심 알고리즘을 직접 구현하세요.

# %%
# 공간 자기상관과 Moran's I 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 공간 자기상관과 Moran's I 방법론의 성능을 비교 분석하세요.

# %%
# 공간 자기상관과 Moran's I 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 공간 자기상관과 Moran's I을 적용하고 결과를 해석하세요.

# %%
# 공간 자기상관과 Moran's I 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
