# %% [markdown]
# # Ch11-10: 실전: 공급망 최적화

# %% [markdown]
# ## 학습 목표
#
# - 실전: 공급망 최적화 이론
# - 실전: 공급망 최적화 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 뉴스벤더: $Q^* = F^{-1}(\frac{c_u}{c_u+c_o})$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np
from scipy import stats
cu, co = 10, 3  # 과소/과다 비용
demand = stats.norm(100, 20)
Q_star = demand.ppf(cu / (cu + co))
print(f"최적 주문량: {Q_star:.1f}")
expected_profit = cu*demand.expect(lambda x: np.minimum(x, Q_star)) - co*demand.expect(lambda x: np.maximum(Q_star-x, 0))
print(f"기대 이익: {expected_profit:.1f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 공급망 최적화의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 공급망 최적화 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 공급망 최적화 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 공급망 최적화 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 공급망 최적화을 적용하고 결과를 해석하세요.

# %%
# 실전: 공급망 최적화 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
