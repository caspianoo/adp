# %% [markdown]
# # Ch11-05: 제약 최적화

# %% [markdown]
# ## 학습 목표
#
# - 제약 최적화 이론
# - 제약 최적화 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 증강 라그랑주: $L_\rho(x,\lambda) = f(x) + \lambda^T h(x) + \frac{\rho}{2}\|h(x)\|^2$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np
from scipy.optimize import minimize
result = minimize(lambda x: x[0]**2+x[1]**2, [1,1],
    constraints={'type':'eq','fun':lambda x: x[0]+x[1]-1})
print(f"최적해: {result.x.round(4)}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 제약 최적화의 핵심 알고리즘을 직접 구현하세요.

# %%
# 제약 최적화 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 제약 최적화 방법론의 성능을 비교 분석하세요.

# %%
# 제약 최적화 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 제약 최적화을 적용하고 결과를 해석하세요.

# %%
# 제약 최적화 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
