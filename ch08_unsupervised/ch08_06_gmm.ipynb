# %% [markdown]
# # Ch08-06: 가우시안 혼합과 EM

# %% [markdown]
# ## 학습 목표
#
# - 가우시안 혼합과 EM 이론
# - 가우시안 혼합과 EM 구현
# - 가우시안 혼합과 EM 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $p(x) = \sum_{k=1}^K \pi_k \mathcal{N}(x|\mu_k, \Sigma_k)$. E: $\gamma_{nk} = \frac{\pi_k\mathcal{N}(x_n|\mu_k,\Sigma_k)}{\sum_j\pi_j\mathcal{N}(x_n|\mu_j,\Sigma_j)}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples=500, centers=3, cluster_std=[1, 1.5, 0.5], random_state=42)
bics = []
for k in range(1, 8):
    gmm = GaussianMixture(n_components=k, random_state=42).fit(X)
    bics.append(gmm.bic(X))
plt.figure(figsize=(8, 5))
plt.plot(range(1, 8), bics, 'b-o')
plt.xlabel('K'); plt.ylabel('BIC')
plt.title(f'최적 K = {np.argmin(bics)+1}')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 가우시안 혼합과 EM의 핵심 알고리즘을 직접 구현하세요.

# %%
# 가우시안 혼합과 EM 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 가우시안 혼합과 EM 방법론의 성능을 비교 분석하세요.

# %%
# 가우시안 혼합과 EM 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 가우시안 혼합과 EM을 적용하고 결과를 해석하세요.

# %%
# 가우시안 혼합과 EM 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
