# %% [markdown]
# # Ch02-04: 몬테카를로 적분과 분산 감소

# %% [markdown]
# ## 학습 목표
#
# - MC 적분의 수렴률과 오차 분석
# - 분산 감소 기법: 대립변량, 제어변량, 층화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# MC 추정: $\hat{I} = \frac{1}{N}\sum f(X_i)$, $\text{Var}(\hat{I}) = \sigma^2/N$, 오차 $O(1/\sqrt{N})$
# 대립변량(antithetic): $\hat{I} = \frac{1}{2N}\sum[f(X_i) + f(1-X_i)]$, 음의 상관이면 분산 감소
# 제어변량: $\hat{I}_c = \hat{I} - c(\bar{g} - E[g])$, 최적 $c^* = \text{Cov}(f,g)/\text{Var}(g)$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

# 몬테카를로 적분과 분산 감소 기본 구현
print("=== 몬테카를로 적분과 분산 감소 ===")

# MC 적분: I = int_0^1 exp(x) dx = e - 1
N = 10000
x = np.random.uniform(0, 1, N)
f_x = np.exp(x)
I_mc = f_x.mean()
I_true = np.e - 1
print(f"MC 추정: {I_mc:.6f}, 참값: {I_true:.6f}, 오차: {abs(I_mc-I_true):.6f}")

# 대립변량법
x_anti = np.random.uniform(0, 1, N//2)
I_anti = 0.5 * (np.exp(x_anti) + np.exp(1 - x_anti)).mean()
print(f"대립변량: {I_anti:.6f}, 분산비: {np.var(f_x)/np.var(0.5*(np.exp(x_anti)+np.exp(1-x_anti))):.2f}x 감소")

# 제어변량
g = x  # E[g] = 0.5
c_opt = -np.cov(f_x, x[:N])[0,1] / np.var(x[:N])
I_control = (f_x + c_opt * (x - 0.5)).mean()
print(f"제어변량: {I_control:.6f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 몬테카를로 적분과 분산 감소의 핵심 알고리즘을 직접 구현하세요.

# %%
# 몬테카를로 적분과 분산 감소 구현
import numpy as np
np.random.seed(42)

# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 몬테카를로 적분과 분산 감소에서 다양한 하이퍼파라미터/조건에 따른 성능을 비교 분석하세요.

# %%
# 몬테카를로 적분과 분산 감소 파라미터 분석
# TODO: 체계적 비교

# %% [markdown]
# ### 문제 3 [★★★]
#
# 몬테카를로 적분과 분산 감소을 실전 문제에 적용하고 결과를 해석하세요.

# %%
# 몬테카를로 적분과 분산 감소 실전 적용
# TODO: 실제 데이터/문제에 적용

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 및 논문 참조
