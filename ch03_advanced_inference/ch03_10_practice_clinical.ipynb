# %% [markdown]
# # Ch03-10: 실전: 임상시험 데이터 분석

# %% [markdown]
# ## 학습 목표
#
# - 실전: 임상시험 데이터 분석의 핵심 이론 이해
# - 실전: 임상시험 데이터 분석의 실전 구현
# - 실전: 임상시험 데이터 분석 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 적응적 설계: 중간 분석 결과에 따라 설계 수정. Alpha-spending: $\alpha^*(t) = 2(1-\Phi(z_\alpha/\sqrt{t}))$ (O'Brien-Fleming). 비열등성: $H_0: \theta_T - \theta_C \leq -\delta$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 실전: 임상시험 데이터 분석 ===")

# 임상시험 시뮬레이션: 2-표본 비교
np.random.seed(42)
n_per_group = 100
effect_size = 0.5

control = np.random.normal(10, 3, n_per_group)
treatment = np.random.normal(10 + effect_size * 3, 3, n_per_group)

# 1. t-검정
t_stat, p_val = stats.ttest_ind(control, treatment)
print(f"t-검정: t={t_stat:.3f}, p={p_val:.4f}")

# 2. 순열 검정
combined = np.concatenate([control, treatment])
n_perm = 10000
perm_stats = []
for _ in range(n_perm):
    perm = np.random.permutation(combined)
    perm_stats.append(perm[:n_per_group].mean() - perm[n_per_group:].mean())
p_perm = np.mean(np.abs(perm_stats) >= np.abs(control.mean() - treatment.mean()))
print(f"순열 검정 p-value: {p_perm:.4f}")

# 3. 검정력 시뮬레이션
powers = []
for n in [20, 50, 100, 200, 500]:
    rejections = 0
    for _ in range(1000):
        c = np.random.normal(10, 3, n)
        t = np.random.normal(10 + effect_size*3, 3, n)
        _, p = stats.ttest_ind(c, t)
        if p < 0.05: rejections += 1
    powers.append(rejections / 1000)
    print(f"n={n}: power={rejections/1000:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 임상시험 데이터 분석의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 임상시험 데이터 분석 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 임상시험 데이터 분석 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 임상시험 데이터 분석 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 임상시험 데이터 분석을 적용하고 결과를 해석하세요.

# %%
# 실전: 임상시험 데이터 분석 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
