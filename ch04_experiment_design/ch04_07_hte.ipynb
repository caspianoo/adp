# %% [markdown]
# # Ch04-07: 이질적 처리 효과 (HTE)

# %% [markdown]
# ## 학습 목표
#
# - 이질적 처리 효과 (HTE) 이론 이해
# - 이질적 처리 효과 (HTE) 구현
# - 이질적 처리 효과 (HTE) 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# CATE: $\tau(x) = E[Y(1) - Y(0) | X = x]$. S-learner: 하나의 모형으로 $\hat\mu(x, w)$. T-learner: $\hat\tau(x) = \hat\mu_1(x) - \hat\mu_0(x)$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
np.random.seed(42)
n = 2000
X = np.random.normal(0, 1, (n, 5))
W = np.random.binomial(1, 0.5, n)
# 이질적 처리 효과: X[:, 0]에 의존
tau_true = 2 * X[:, 0]
Y = X[:, 0] + X[:, 1]**2 + tau_true * W + np.random.normal(0, 1, n)

# T-learner
model_1 = RandomForestRegressor(n_estimators=100, random_state=42).fit(X[W==1], Y[W==1])
model_0 = RandomForestRegressor(n_estimators=100, random_state=42).fit(X[W==0], Y[W==0])
tau_hat = model_1.predict(X) - model_0.predict(X)

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(tau_true, tau_hat, alpha=0.1, s=5)
plt.plot([-6, 6], [-6, 6], 'r--')
plt.xlabel('True CATE'); plt.ylabel('Estimated CATE')
plt.title(f'T-Learner HTE (corr={np.corrcoef(tau_true, tau_hat)[0,1]:.3f})')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 이질적 처리 효과 (HTE)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 이질적 처리 효과 (HTE) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 이질적 처리 효과 (HTE) 방법론의 성능을 비교 분석하세요.

# %%
# 이질적 처리 효과 (HTE) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 이질적 처리 효과 (HTE)을 적용하고 결과를 해석하세요.

# %%
# 이질적 처리 효과 (HTE) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
