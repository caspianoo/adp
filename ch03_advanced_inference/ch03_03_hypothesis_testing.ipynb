# %% [markdown]
# # Ch03-03: 우도비 검정과 Wald 검정

# %% [markdown]
# ## 학습 목표
#
# - 우도비 검정과 Wald 검정의 핵심 이론 이해
# - 우도비 검정과 Wald 검정의 실전 구현
# - 우도비 검정과 Wald 검정 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# LRT: $\Lambda = -2\log\frac{L(\theta_0)}{L(\hat\theta)} \xrightarrow{d} \chi^2_k$, Wald: $W = (\hat\theta - \theta_0)^T I(\hat\theta) (\hat\theta - \theta_0) \xrightarrow{d} \chi^2_k$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 우도비 검정과 Wald 검정 ===")

# 우도비 검정 예시: 정규 분포 평균 검정
n = 50
mu0 = 5.0
data = np.random.normal(5.3, 2, n)
mu_hat = data.mean()
sigma_hat = data.std()

# LRT 통계량
ll_null = np.sum(stats.norm.logpdf(data, mu0, sigma_hat))
ll_alt = np.sum(stats.norm.logpdf(data, mu_hat, sigma_hat))
lrt = -2 * (ll_null - ll_alt)
p_lrt = 1 - stats.chi2.cdf(lrt, df=1)

# Wald 검정
se = sigma_hat / np.sqrt(n)
wald = ((mu_hat - mu0) / se) ** 2
p_wald = 1 - stats.chi2.cdf(wald, df=1)

print(f"LRT: stat={lrt:.4f}, p={p_lrt:.4f}")
print(f"Wald: stat={wald:.4f}, p={p_wald:.4f}")
print(f"t-test p: {stats.ttest_1samp(data, mu0).pvalue:.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 우도비 검정과 Wald 검정의 핵심 알고리즘을 직접 구현하세요.

# %%
# 우도비 검정과 Wald 검정 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 우도비 검정과 Wald 검정 방법론의 성능을 비교 분석하세요.

# %%
# 우도비 검정과 Wald 검정 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 우도비 검정과 Wald 검정을 적용하고 결과를 해석하세요.

# %%
# 우도비 검정과 Wald 검정 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
