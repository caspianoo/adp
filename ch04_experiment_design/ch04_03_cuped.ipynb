# %% [markdown]
# # Ch04-03: CUPED와 분산 감소

# %% [markdown]
# ## 학습 목표
#
# - CUPED와 분산 감소 이론 이해
# - CUPED와 분산 감소 구현
# - CUPED와 분산 감소 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# CUPED: $\hat\tau_{adj} = \hat\tau - \theta(\bar{X}_{pre}^T - \bar{X}_{pre}^C)$. 분산 감소: $1 - \rho^2$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
np.random.seed(42)
n = 5000

X_pre = np.random.normal(100, 20, n)
tau = 2.0
treatment = np.random.binomial(1, 0.5, n)
Y = X_pre * 0.8 + tau * treatment + np.random.normal(0, 10, n)

# 단순 추정
tau_simple = Y[treatment==1].mean() - Y[treatment==0].mean()

# CUPED
theta = np.cov(Y, X_pre)[0,1] / np.var(X_pre)
Y_adj = Y - theta * (X_pre - X_pre.mean())
tau_cuped = Y_adj[treatment==1].mean() - Y_adj[treatment==0].mean()

rho = np.corrcoef(Y, X_pre)[0,1]
print(f"단순 추정: {tau_simple:.4f}, SE: {np.sqrt(np.var(Y)/n*4):.4f}")
print(f"CUPED 추정: {tau_cuped:.4f}, SE: {np.sqrt(np.var(Y_adj)/n*4):.4f}")
print(f"분산 감소: {(1-rho**2)*100:.1f}% 잔여 ({rho**2*100:.1f}% 감소)")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# CUPED와 분산 감소의 핵심 알고리즘을 직접 구현하세요.

# %%
# CUPED와 분산 감소 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 CUPED와 분산 감소 방법론의 성능을 비교 분석하세요.

# %%
# CUPED와 분산 감소 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 CUPED와 분산 감소을 적용하고 결과를 해석하세요.

# %%
# CUPED와 분산 감소 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
