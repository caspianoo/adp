# %% [markdown]
# # Ch09-09: 매개 분석

# %% [markdown]
# ## 학습 목표
#
# - 매개 분석 이론
# - 매개 분석 구현
# - 매개 분석 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 총 효과 = 직접 효과 + 간접 효과. $NDE = E[Y(1,M(0)) - Y(0,M(0))]$. $NIE = E[Y(0,M(1)) - Y(0,M(0))]$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
np.random.seed(42)
n = 2000
X = np.random.binomial(1, 0.5, n)
M = 0.5*X + np.random.normal(0, 1, n)
Y = 1.5*X + 0.8*M + np.random.normal(0, 1, n)
total = np.mean(Y[X==1]) - np.mean(Y[X==0])
# Baron-Kenny
from sklearn.linear_model import LinearRegression
a = LinearRegression().fit(X.reshape(-1,1), M).coef_[0]
b_direct = LinearRegression().fit(np.column_stack([X, M]), Y).coef_
indirect = a * b_direct[1]
direct = b_direct[0]
print(f"총 효과: {total:.3f}, 직접: {direct:.3f}, 간접: {indirect:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 매개 분석의 핵심 알고리즘을 직접 구현하세요.

# %%
# 매개 분석 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 매개 분석 방법론의 성능을 비교 분석하세요.

# %%
# 매개 분석 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 매개 분석을 적용하고 결과를 해석하세요.

# %%
# 매개 분석 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
