# %% [markdown]
# # Ch02-09: 시뮬레이션 기반 추론 (ABC)

# %% [markdown]
# ## 학습 목표
#
# - 근사 베이지안 계산의 원리
# - 요약 통계량 선택의 중요성
# - ABC-SMC와 적응적 방법

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# ABC: $\theta^* \sim \pi(\theta)$로 생성, $y^* \sim p(y|\theta^*)$ 시뮬레이션, $d(S(y^*), S(y_{obs})) < \epsilon$이면 수락
# $\epsilon \to 0$이면 정확한 사후 분포에 수렴하지만 수용률도 0에 수렴
# ABC-SMC: 점진적으로 $\epsilon$을 줄이면서 입자 필터 적용

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

# 시뮬레이션 기반 추론 (ABC) 기본 구현
print("=== 시뮬레이션 기반 추론 (ABC) ===")

# ABC: 정규 분포의 평균과 분산 추론
observed = np.random.normal(5, 2, 50)
obs_mean, obs_std = observed.mean(), observed.std()

n_samples = 100000
epsilon = 0.5
accepted_params = []

for _ in range(n_samples):
    mu = np.random.uniform(0, 10)
    sigma = np.random.uniform(0.1, 5)
    simulated = np.random.normal(mu, sigma, 50)
    sim_mean, sim_std = simulated.mean(), simulated.std()

    dist = np.sqrt((sim_mean - obs_mean)**2 + (sim_std - obs_std)**2)
    if dist < epsilon:
        accepted_params.append((mu, sigma))

params = np.array(accepted_params)
print(f"수용률: {len(params)/n_samples:.4f}")
print(f"ABC 사후 평균: mu={params[:,0].mean():.3f}, sigma={params[:,1].mean():.3f}")
print(f"관측 통계량: mean={obs_mean:.3f}, std={obs_std:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 시뮬레이션 기반 추론 (ABC)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 시뮬레이션 기반 추론 (ABC) 구현
import numpy as np
np.random.seed(42)

# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 시뮬레이션 기반 추론 (ABC)에서 다양한 하이퍼파라미터/조건에 따른 성능을 비교 분석하세요.

# %%
# 시뮬레이션 기반 추론 (ABC) 파라미터 분석
# TODO: 체계적 비교

# %% [markdown]
# ### 문제 3 [★★★]
#
# 시뮬레이션 기반 추론 (ABC)을 실전 문제에 적용하고 결과를 해석하세요.

# %%
# 시뮬레이션 기반 추론 (ABC) 실전 적용
# TODO: 실제 데이터/문제에 적용

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 및 논문 참조
