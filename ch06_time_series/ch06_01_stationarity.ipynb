# %% [markdown]
# # Ch06-01: 정상성과 단위근 검정

# %% [markdown]
# ## 학습 목표
#
# - 정상성과 단위근 검정 이론
# - 정상성과 단위근 검정 구현
# - 정상성과 단위근 검정 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 약정상: $E[X_t] = \mu$, $\text{Cov}(X_t, X_{t+h}) = \gamma(h)$. ADF: $\Delta y_t = \alpha + \beta t + \gamma y_{t-1} + \sum \delta_i \Delta y_{t-i} + \epsilon_t$, $H_0: \gamma = 0$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
from statsmodels.tsa.stattools import adfuller, kpss

np.random.seed(42)
n = 500
# 정상 시계열 (AR(1))
y_stat = np.zeros(n)
for t in range(1, n): y_stat[t] = 0.7*y_stat[t-1] + np.random.normal(0, 1)
# 비정상 (랜덤 워크)
y_nonstat = np.cumsum(np.random.normal(0, 1, n))

for name, y in [('정상 AR(1)', y_stat), ('랜덤 워크', y_nonstat)]:
    adf_stat, adf_p, *_ = adfuller(y)
    kpss_stat, kpss_p, *_ = kpss(y, regression='c', nlags='auto')
    print(f"{name}: ADF p={adf_p:.4f}, KPSS p={kpss_p:.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 정상성과 단위근 검정의 핵심 알고리즘을 직접 구현하세요.

# %%
# 정상성과 단위근 검정 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 정상성과 단위근 검정 방법론의 성능을 비교 분석하세요.

# %%
# 정상성과 단위근 검정 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 정상성과 단위근 검정을 적용하고 결과를 해석하세요.

# %%
# 정상성과 단위근 검정 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
