# %% [markdown]
# # Ch07-10: 실전: 스포츠 베이지안 순위

# %% [markdown]
# ## 학습 목표
#
# - 실전: 스포츠 베이지안 순위 이론
# - 실전: 스포츠 베이지안 순위 구현
# - 실전: 스포츠 베이지안 순위 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# Bradley-Terry: $P(i \text{ beats } j) = \frac{p_i}{p_i + p_j}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
np.random.seed(42)
n_teams = 6
strengths = np.array([3.0, 2.5, 2.0, 1.5, 1.0, 0.5])
names = ['팀A', '팀B', '팀C', '팀D', '팀E', '팀F']
# 경기 시뮬레이션
results = []
for i in range(n_teams):
    for j in range(i+1, n_teams):
        for _ in range(10):
            p = strengths[i] / (strengths[i] + strengths[j])
            winner = i if np.random.rand() < p else j
            results.append((i, j, winner))

# MLE 추정 (반복 비례)
s = np.ones(n_teams)
for _ in range(100):
    for k in range(n_teams):
        wins = sum(1 for i,j,w in results if w == k)
        games = sum(1/(s[i]+s[j]) for i,j,w in results if i==k or j==k)
        s[k] = wins / games if games > 0 else 1
    s /= s.sum()

for name, st in sorted(zip(names, s), key=lambda x: -x[1]):
    print(f"{name}: {st:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 스포츠 베이지안 순위의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 스포츠 베이지안 순위 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 스포츠 베이지안 순위 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 스포츠 베이지안 순위 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 스포츠 베이지안 순위을 적용하고 결과를 해석하세요.

# %%
# 실전: 스포츠 베이지안 순위 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
