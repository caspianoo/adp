# %% [markdown]
# # Ch08-10: 실전: 고객 세분화

# %% [markdown]
# ## 학습 목표
#
# - 실전: 고객 세분화 이론
# - 실전: 고객 세분화 구현
# - 실전: 고객 세분화 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# RFM 분석 + 클러스터링으로 고객 세그먼트 도출

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, pandas as pd
np.random.seed(42)
n = 1000
df = pd.DataFrame({
    'recency': np.random.exponential(30, n),
    'frequency': np.random.poisson(5, n),
    'monetary': np.random.lognormal(4, 1, n)
})
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
X = StandardScaler().fit_transform(df)
km = KMeans(4, random_state=42, n_init=10).fit(X)
df['segment'] = km.labels_
print(df.groupby('segment')[['recency','frequency','monetary']].mean().round(1))

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 고객 세분화의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 고객 세분화 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 고객 세분화 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 고객 세분화 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 고객 세분화을 적용하고 결과를 해석하세요.

# %%
# 실전: 고객 세분화 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
