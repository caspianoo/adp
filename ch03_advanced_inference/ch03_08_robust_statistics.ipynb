# %% [markdown]
# # Ch03-08: 로버스트 통계

# %% [markdown]
# ## 학습 목표
#
# - 로버스트 통계의 핵심 이론 이해
# - 로버스트 통계의 실전 구현
# - 로버스트 통계 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# M-추정: $\hat\theta = \arg\min \sum \rho(x_i - \theta)$. Huber 함수: $\rho_k(x) = \begin{cases} x^2/2 & |x|\leq k \\ k|x|-k^2/2 & |x|>k \end{cases}$. 붕괴점(breakdown point): 추정량이 무한대가 되기 전에 오염 가능한 최대 비율

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 로버스트 통계 ===")

# Huber M-추정량
def huber_loss(r, k=1.345):
    return np.where(np.abs(r) <= k, 0.5 * r**2, k * np.abs(r) - 0.5 * k**2)

def huber_psi(r, k=1.345):
    return np.where(np.abs(r) <= k, r, k * np.sign(r))

# 오염된 데이터
np.random.seed(42)
data = np.concatenate([np.random.normal(5, 1, 90), np.random.normal(20, 1, 10)])

# IRLS (Iteratively Reweighted Least Squares)
mu = np.median(data)
for _ in range(100):
    resid = data - mu
    s = 1.4826 * np.median(np.abs(resid))
    w = huber_psi(resid / s) / (resid / s + 1e-10)
    w = np.clip(w, 0, 1)
    mu_new = np.average(data, weights=np.abs(w))
    if abs(mu_new - mu) < 1e-6: break
    mu = mu_new

print(f"평균: {data.mean():.3f}")
print(f"중위수: {np.median(data):.3f}")
print(f"Huber M-추정: {mu:.3f}")
print(f"참값: 5.0")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 로버스트 통계의 핵심 알고리즘을 직접 구현하세요.

# %%
# 로버스트 통계 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 로버스트 통계 방법론의 성능을 비교 분석하세요.

# %%
# 로버스트 통계 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 로버스트 통계을 적용하고 결과를 해석하세요.

# %%
# 로버스트 통계 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
