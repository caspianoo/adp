# %% [markdown]
# # Ch11-08: 강화학습 기초

# %% [markdown]
# ## 학습 목표
#
# - 강화학습 기초 이론
# - 강화학습 기초 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# Bellman: $V(s) = \max_a [R(s,a) + \gamma \sum P(s'|s,a)V(s')]$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np
# Q-learning: GridWorld
grid_size = 4; n_actions = 4; gamma = 0.99; alpha = 0.1
Q = np.zeros((grid_size**2, n_actions))
goal = grid_size**2 - 1
for episode in range(1000):
    state = 0
    for _ in range(100):
        if np.random.rand() < 0.1: action = np.random.randint(4)
        else: action = np.argmax(Q[state])
        row, col = state//grid_size, state%grid_size
        if action==0: row=max(0,row-1)
        elif action==1: row=min(grid_size-1,row+1)
        elif action==2: col=max(0,col-1)
        else: col=min(grid_size-1,col+1)
        next_state = row*grid_size+col
        reward = 1 if next_state==goal else -0.01
        Q[state,action] += alpha*(reward+gamma*Q[next_state].max()-Q[state,action])
        state = next_state
        if state == goal: break
print("Q-table 최적 정책:")
print(np.array(['↑','↓','←','→'])[Q.argmax(axis=1)].reshape(grid_size,grid_size))

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 강화학습 기초의 핵심 알고리즘을 직접 구현하세요.

# %%
# 강화학습 기초 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 강화학습 기초 방법론의 성능을 비교 분석하세요.

# %%
# 강화학습 기초 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 강화학습 기초을 적용하고 결과를 해석하세요.

# %%
# 강화학습 기초 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
