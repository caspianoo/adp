# %% [markdown]
# # Ch07-08: 가우시안 과정 회귀

# %% [markdown]
# ## 학습 목표
#
# - 가우시안 과정 회귀 이론
# - 가우시안 과정 회귀 구현
# - 가우시안 과정 회귀 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# GP: $f \sim \mathcal{GP}(m, k)$. RBF 커널: $k(x,x') = \sigma^2\exp(-\frac{\|x-x'\|^2}{2l^2})$. 사후: $f_*|X_*,X,y \sim N(\bar{f}_*, \text{cov}(f_*))$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
# GP 회귀 from scratch
def rbf_kernel(x1, x2, l=1.0, sigma=1.0):
    return sigma**2 * np.exp(-0.5*np.subtract.outer(x1, x2)**2 / l**2)

X_train = np.array([-4, -3, -2, -1, 1, 2, 3, 4.0])
y_train = np.sin(X_train) + 0.1*np.random.randn(len(X_train))
X_test = np.linspace(-6, 6, 200)

K = rbf_kernel(X_train, X_train) + 0.01*np.eye(len(X_train))
K_s = rbf_kernel(X_train, X_test)
K_ss = rbf_kernel(X_test, X_test)

K_inv = np.linalg.inv(K)
mu = K_s.T @ K_inv @ y_train
cov = K_ss - K_s.T @ K_inv @ K_s

plt.figure(figsize=(12, 6))
plt.plot(X_test, mu, 'b-', label='GP 평균')
plt.fill_between(X_test, mu-2*np.sqrt(np.diag(cov)), mu+2*np.sqrt(np.diag(cov)), alpha=0.2)
plt.scatter(X_train, y_train, c='red', s=100, zorder=5)
plt.plot(X_test, np.sin(X_test), 'k--', alpha=0.5, label='sin(x)')
plt.legend(); plt.title('가우시안 과정 회귀')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 가우시안 과정 회귀의 핵심 알고리즘을 직접 구현하세요.

# %%
# 가우시안 과정 회귀 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 가우시안 과정 회귀 방법론의 성능을 비교 분석하세요.

# %%
# 가우시안 과정 회귀 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 가우시안 과정 회귀을 적용하고 결과를 해석하세요.

# %%
# 가우시안 과정 회귀 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
