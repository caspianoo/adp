# %% [markdown]
# # Ch06-08: 변환점 탐지

# %% [markdown]
# ## 학습 목표
#
# - 변환점 탐지 이론
# - 변환점 탐지 구현
# - 변환점 탐지 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# CUSUM: $S_t = \sum_{i=1}^t (x_i - \bar{x})$. PELT: $\min_{m, \tau} \sum_{i=0}^m C(y_{\tau_i+1:\tau_{i+1}}) + \beta m$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
y = np.concatenate([np.random.normal(0, 1, 100), np.random.normal(3, 1, 100), np.random.normal(1, 1, 100)])
# CUSUM
cusum = np.cumsum(y - y.mean())
plt.figure(figsize=(12, 4))
plt.subplot(1,2,1); plt.plot(y); plt.title('시계열')
plt.subplot(1,2,2); plt.plot(cusum); plt.title('CUSUM')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 변환점 탐지의 핵심 알고리즘을 직접 구현하세요.

# %%
# 변환점 탐지 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 변환점 탐지 방법론의 성능을 비교 분석하세요.

# %%
# 변환점 탐지 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 변환점 탐지을 적용하고 결과를 해석하세요.

# %%
# 변환점 탐지 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
