# %% [markdown]
# # Ch11-04: 경사 하강법

# %% [markdown]
# ## 학습 목표
#
# - 경사 하강법 이론
# - 경사 하강법 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $x_{k+1} = x_k - \alpha_k \nabla f(x_k)$. 수렴: $f(x_k) - f^* \leq \frac{L\|x_0 - x^*\|^2}{2k}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np, matplotlib.pyplot as plt
def rosenbrock(x): return (1-x[0])**2 + 100*(x[1]-x[0]**2)**2
def grad_rosenbrock(x): return np.array([-2*(1-x[0])-400*x[0]*(x[1]-x[0]**2), 200*(x[1]-x[0]**2)])

x = np.array([-1.0, 1.0]); lr = 0.001; history = [x.copy()]
for _ in range(10000):
    x = x - lr * grad_rosenbrock(x)
    history.append(x.copy())
history = np.array(history)
print(f"최종: {x.round(6)}, f={rosenbrock(x):.8f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 경사 하강법의 핵심 알고리즘을 직접 구현하세요.

# %%
# 경사 하강법 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 경사 하강법 방법론의 성능을 비교 분석하세요.

# %%
# 경사 하강법 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 경사 하강법을 적용하고 결과를 해석하세요.

# %%
# 경사 하강법 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
