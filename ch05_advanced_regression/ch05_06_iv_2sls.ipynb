# %% [markdown]
# # Ch05-06: 도구 변수와 2SLS

# %% [markdown]
# ## 학습 목표
#
# - 도구 변수와 2SLS 이론
# - 도구 변수와 2SLS 구현
# - 도구 변수와 2SLS 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 내생성: $\text{Cov}(X, \epsilon) \neq 0$. IV 조건: 관련성 $\text{Cov}(Z, X) \neq 0$, 제외 $\text{Cov}(Z, \epsilon) = 0$. 2SLS: 1단계 $\hat{X} = Z\hat\gamma$, 2단계 $Y = \hat{X}\beta + u$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

np.random.seed(42)
n = 1000
# 교란 변수
U = np.random.normal(0, 1, n)
# 도구 변수 (U와 독립)
Z = np.random.normal(0, 1, n)
# 내생 변수 (U에 의존)
X = 0.5*Z + 0.8*U + np.random.normal(0, 0.5, n)
# 결과 (참 효과 = 2)
Y = 2*X + 1.5*U + np.random.normal(0, 1, n)

# OLS (편향)
ols = LinearRegression().fit(X.reshape(-1,1), Y)
print(f"OLS 추정: {ols.coef_[0]:.3f} (편향됨, 참=2)")

# 2SLS
stage1 = LinearRegression().fit(Z.reshape(-1,1), X)
X_hat = stage1.predict(Z.reshape(-1,1))
stage2 = LinearRegression().fit(X_hat.reshape(-1,1), Y)
print(f"2SLS 추정: {stage2.coef_[0]:.3f}")
print(f"1단계 F-stat: {(stage1.score(Z.reshape(-1,1), X) * n) / (1 - stage1.score(Z.reshape(-1,1), X)):.1f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 도구 변수와 2SLS의 핵심 알고리즘을 직접 구현하세요.

# %%
# 도구 변수와 2SLS 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 도구 변수와 2SLS 방법론의 성능을 비교 분석하세요.

# %%
# 도구 변수와 2SLS 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 도구 변수와 2SLS을 적용하고 결과를 해석하세요.

# %%
# 도구 변수와 2SLS 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
