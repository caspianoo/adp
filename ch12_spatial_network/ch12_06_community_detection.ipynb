# %% [markdown]
# # Ch12-06: 커뮤니티 탐지

# %% [markdown]
# ## 학습 목표
#
# - 커뮤니티 탐지 이론
# - 커뮤니티 탐지 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 모듈성: $Q = \frac{1}{2m}\sum_{ij}(A_{ij} - \frac{k_ik_j}{2m})\delta(c_i, c_j)$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

import networkx as nx
import matplotlib.pyplot as plt
G = nx.karate_club_graph()
communities = nx.community.greedy_modularity_communities(G)
colors = {}
for i, comm in enumerate(communities):
    for node in comm: colors[node] = i
nx.draw_spring(G, node_color=[colors[n] for n in G.nodes()], cmap='Set1', node_size=200)
plt.title(f'커뮤니티 탐지 ({len(communities)}개)')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 커뮤니티 탐지의 핵심 알고리즘을 직접 구현하세요.

# %%
# 커뮤니티 탐지 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 커뮤니티 탐지 방법론의 성능을 비교 분석하세요.

# %%
# 커뮤니티 탐지 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 커뮤니티 탐지을 적용하고 결과를 해석하세요.

# %%
# 커뮤니티 탐지 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
