# %% [markdown]
# # Ch12-03: 점 과정과 공간 밀도

# %% [markdown]
# ## 학습 목표
#
# - 점 과정과 공간 밀도 이론
# - 점 과정과 공간 밀도 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# K-함수: $K(r) = \lambda^{-1}E[\text{# points within r}]$. CSR: $K(r) = \pi r^2$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
# 동질 포아송 과정
lam = 50; area = 10
n = np.random.poisson(lam * area**2)
x = np.random.uniform(0, area, n); y = np.random.uniform(0, area, n)
plt.figure(figsize=(6, 6))
plt.scatter(x, y, s=5)
plt.title(f'동질 포아송 과정 (λ={lam}, n={n})')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 점 과정과 공간 밀도의 핵심 알고리즘을 직접 구현하세요.

# %%
# 점 과정과 공간 밀도 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 점 과정과 공간 밀도 방법론의 성능을 비교 분석하세요.

# %%
# 점 과정과 공간 밀도 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 점 과정과 공간 밀도을 적용하고 결과를 해석하세요.

# %%
# 점 과정과 공간 밀도 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
