# %% [markdown]
# # Ch04-01: 검정력 분석과 표본 크기 설계

# %% [markdown]
# ## 학습 목표
#
# - 검정력 분석과 표본 크기 설계 이론 이해
# - 검정력 분석과 표본 크기 설계 구현
# - 검정력 분석과 표본 크기 설계 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 검정력 $1-\beta = P(\text{reject } H_0 | H_1 \text{ true})$. 표본 크기: $n = \frac{(z_{\alpha/2} + z_\beta)^2 \cdot 2\sigma^2}{\delta^2}$

# %% [markdown]
# ## 구현 가이드

# %%
from scipy.stats import norm
import numpy as np, matplotlib.pyplot as plt

def sample_size_two_means(delta, sigma, alpha=0.05, power=0.8):
    z_alpha = norm.ppf(1 - alpha/2)
    z_beta = norm.ppf(power)
    return int(np.ceil(2 * ((z_alpha + z_beta) * sigma / delta) ** 2))

# 효과 크기에 따른 표본 크기
deltas = np.linspace(0.1, 1.0, 50)
ns = [sample_size_two_means(d, sigma=1) for d in deltas]

plt.figure(figsize=(10, 6))
plt.plot(deltas, ns, 'b-o', markersize=3)
plt.xlabel('효과 크기 (δ/σ)'); plt.ylabel('그룹별 표본 크기')
plt.title('효과 크기 vs 필요 표본 크기 (power=0.8, α=0.05)')
plt.yscale('log'); plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 검정력 분석과 표본 크기 설계의 핵심 알고리즘을 직접 구현하세요.

# %%
# 검정력 분석과 표본 크기 설계 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 검정력 분석과 표본 크기 설계 방법론의 성능을 비교 분석하세요.

# %%
# 검정력 분석과 표본 크기 설계 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 검정력 분석과 표본 크기 설계을 적용하고 결과를 해석하세요.

# %%
# 검정력 분석과 표본 크기 설계 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
