# %% [markdown]
# # Ch06-10: 실전: 에너지 수요 예측

# %% [markdown]
# ## 학습 목표
#
# - 실전: 에너지 수요 예측 이론
# - 실전: 에너지 수요 예측 구현
# - 실전: 에너지 수요 예측 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 다중 계절성 + 외생 변수 활용 예측

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
t = np.arange(365*2)
daily = 10*np.sin(2*np.pi*t/365)
weekly = 3*np.sin(2*np.pi*t/7)
trend = 0.01*t
y = 100 + trend + daily + weekly + np.random.normal(0, 2, len(t))
plt.figure(figsize=(14, 5))
plt.plot(t, y, alpha=0.7); plt.title('합성 에너지 수요 데이터')
plt.xlabel('일'); plt.ylabel('수요')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 에너지 수요 예측의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 에너지 수요 예측 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 에너지 수요 예측 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 에너지 수요 예측 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 에너지 수요 예측을 적용하고 결과를 해석하세요.

# %%
# 실전: 에너지 수요 예측 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
