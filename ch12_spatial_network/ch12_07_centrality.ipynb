# %% [markdown]
# # Ch12-07: 중심성과 영향력 전파

# %% [markdown]
# ## 학습 목표
#
# - 중심성과 영향력 전파 이론
# - 중심성과 영향력 전파 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# Betweenness: $c_B(v) = \sum_{s\neq v \neq t}\frac{\sigma_{st}(v)}{\sigma_{st}}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

import networkx as nx
G = nx.karate_club_graph()
cent = nx.betweenness_centrality(G)
top5 = sorted(cent.items(), key=lambda x: -x[1])[:5]
print("Betweenness 상위 5:")
for node, val in top5: print(f"  Node {node}: {val:.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 중심성과 영향력 전파의 핵심 알고리즘을 직접 구현하세요.

# %%
# 중심성과 영향력 전파 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 중심성과 영향력 전파 방법론의 성능을 비교 분석하세요.

# %%
# 중심성과 영향력 전파 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 중심성과 영향력 전파을 적용하고 결과를 해석하세요.

# %%
# 중심성과 영향력 전파 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
