# %% [markdown]
# # Ch12-10: 실전: 전염병 확산 모델링

# %% [markdown]
# ## 학습 목표
#
# - 실전: 전염병 확산 모델링 이론
# - 실전: 전염병 확산 모델링 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# SIR: $\frac{dS}{dt}=-\beta SI/N$, $\frac{dI}{dt}=\beta SI/N - \gamma I$, $R_0 = \beta/\gamma$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

import numpy as np, matplotlib.pyplot as plt
from scipy.integrate import odeint
def sir(y, t, beta, gamma, N):
    S, I, R = y
    return [-beta*S*I/N, beta*S*I/N - gamma*I, gamma*I]
N = 10000; I0 = 10; R0_val = 2.5; gamma = 0.1; beta = R0_val * gamma
t = np.linspace(0, 160, 1000)
sol = odeint(sir, [N-I0, I0, 0], t, args=(beta, gamma, N))
plt.figure(figsize=(10, 6))
plt.plot(t, sol[:,0], label='S'); plt.plot(t, sol[:,1], label='I'); plt.plot(t, sol[:,2], label='R')
plt.xlabel('일'); plt.ylabel('인구'); plt.title(f'SIR 모형 (R₀={R0_val})')
plt.legend(); plt.show()
print(f"최대 감염: {sol[:,1].max():.0f}명 ({sol[:,1].max()/N*100:.1f}%)")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 실전: 전염병 확산 모델링의 핵심 알고리즘을 직접 구현하세요.

# %%
# 실전: 전염병 확산 모델링 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 실전: 전염병 확산 모델링 방법론의 성능을 비교 분석하세요.

# %%
# 실전: 전염병 확산 모델링 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 실전: 전염병 확산 모델링을 적용하고 결과를 해석하세요.

# %%
# 실전: 전염병 확산 모델링 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
