# %% [markdown]
# # Ch05-04: 일반화 가법 모형 (GAM)

# %% [markdown]
# ## 학습 목표
#
# - 일반화 가법 모형 (GAM) 이론
# - 일반화 가법 모형 (GAM) 구현
# - 일반화 가법 모형 (GAM) 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# GAM: $g(E[Y]) = \alpha + \sum_{j=1}^p f_j(X_j)$. 각 $f_j$는 스플라인으로 추정, 페널티: $\lambda_j \int f_j''(x)^2 dx$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from sklearn.preprocessing import SplineTransformer
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline

np.random.seed(42)
n = 500
X1 = np.random.uniform(0, 2*np.pi, n)
X2 = np.random.uniform(0, 5, n)
Y = np.sin(X1) + 0.5*X2**2 + np.random.normal(0, 0.5, n)

# 스플라인 기반 GAM 근사
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
for ax, x, name in zip(axes, [X1, X2], ['X1', 'X2']):
    pipe = make_pipeline(SplineTransformer(n_knots=10, degree=3), Ridge(alpha=1.0))
    pipe.fit(x.reshape(-1, 1), Y)
    x_plot = np.linspace(x.min(), x.max(), 200).reshape(-1, 1)
    ax.scatter(x, Y, alpha=0.1, s=5)
    ax.plot(x_plot, pipe.predict(x_plot), 'r-', lw=2)
    ax.set_title(f'f({name})')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 일반화 가법 모형 (GAM)의 핵심 알고리즘을 직접 구현하세요.

# %%
# 일반화 가법 모형 (GAM) 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 일반화 가법 모형 (GAM) 방법론의 성능을 비교 분석하세요.

# %%
# 일반화 가법 모형 (GAM) 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 일반화 가법 모형 (GAM)을 적용하고 결과를 해석하세요.

# %%
# 일반화 가법 모형 (GAM) 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
