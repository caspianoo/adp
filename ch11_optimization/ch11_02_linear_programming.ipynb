# %% [markdown]
# # Ch11-02: 선형 계획법

# %% [markdown]
# ## 학습 목표
#
# - 선형 계획법 이론
# - 선형 계획법 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $\min c^Tx$ s.t. $Ax \leq b$, $x \geq 0$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np
from scipy.optimize import linprog
c = [-5, -4]
A_ub = [[6, 4], [1, 2], [-1, 1]]
b_ub = [24, 6, 1]
result = linprog(c, A_ub=A_ub, b_ub=b_ub, bounds=[(0,None),(0,None)])
print(f"최적해: {result.x.round(3)}, 최적값: {-result.fun:.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 선형 계획법의 핵심 알고리즘을 직접 구현하세요.

# %%
# 선형 계획법 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 선형 계획법 방법론의 성능을 비교 분석하세요.

# %%
# 선형 계획법 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 선형 계획법을 적용하고 결과를 해석하세요.

# %%
# 선형 계획법 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
