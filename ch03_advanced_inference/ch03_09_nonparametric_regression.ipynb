# %% [markdown]
# # Ch03-09: 함수 추정과 비모수 회귀

# %% [markdown]
# ## 학습 목표
#
# - 함수 추정과 비모수 회귀의 핵심 이론 이해
# - 함수 추정과 비모수 회귀의 실전 구현
# - 함수 추정과 비모수 회귀 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# Nadaraya-Watson: $\hat{m}(x) = \frac{\sum K_h(x-X_i)Y_i}{\sum K_h(x-X_i)}$. 국소 다항식: 각 $x$에서 가중 최소제곱. 스플라인: $\min \sum(y_i - f(x_i))^2 + \lambda\int f''(x)^2 dx$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 함수 추정과 비모수 회귀 ===")

# Nadaraya-Watson 커널 회귀
np.random.seed(42)
n = 200
X = np.sort(np.random.uniform(0, 2*np.pi, n))
Y = np.sin(X) + 0.3 * np.random.randn(n)

def nadaraya_watson(X_train, Y_train, X_test, h=0.3):
    K = np.exp(-0.5 * ((X_test[:, None] - X_train[None, :]) / h) ** 2)
    return (K * Y_train[None, :]).sum(axis=1) / K.sum(axis=1)

x_test = np.linspace(0, 2*np.pi, 500)
fig, axes = plt.subplots(1, 3, figsize=(18, 5))
for ax, h in zip(axes, [0.1, 0.3, 1.0]):
    y_hat = nadaraya_watson(X, Y, x_test, h)
    ax.scatter(X, Y, alpha=0.3, s=10)
    ax.plot(x_test, y_hat, 'r-', lw=2, label=f'NW (h={h})')
    ax.plot(x_test, np.sin(x_test), 'k--', lw=1, label='sin(x)')
    ax.legend(); ax.set_title(f'h = {h}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 함수 추정과 비모수 회귀의 핵심 알고리즘을 직접 구현하세요.

# %%
# 함수 추정과 비모수 회귀 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 함수 추정과 비모수 회귀 방법론의 성능을 비교 분석하세요.

# %%
# 함수 추정과 비모수 회귀 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 함수 추정과 비모수 회귀을 적용하고 결과를 해석하세요.

# %%
# 함수 추정과 비모수 회귀 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
