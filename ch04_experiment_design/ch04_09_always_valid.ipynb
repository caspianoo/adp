# %% [markdown]
# # Ch04-09: 연속 모니터링과 항시 유효한 추론

# %% [markdown]
# ## 학습 목표
#
# - 연속 모니터링과 항시 유효한 추론 이론 이해
# - 연속 모니터링과 항시 유효한 추론 구현
# - 연속 모니터링과 항시 유효한 추론 실전 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# 항시 유효 CI: $\hat\mu_t \pm \sqrt{\frac{2\hat\sigma^2}{t}(1 + \frac{1}{t})\log(\frac{2\sqrt{t+1}}{\alpha})}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
n_max = 5000; delta = 0.5
data = np.random.normal(delta, 1, n_max)

# 고정 표본 CI vs 항시 유효 CI
fig, ax = plt.subplots(figsize=(12, 6))
ns = range(10, n_max, 10)
fixed_reject, valid_reject = [], []
for n in ns:
    x_bar = data[:n].mean()
    se = data[:n].std() / np.sqrt(n)
    # 고정 표본 (naive)
    fixed_reject.append(abs(x_bar) > 1.96 * se)
    # 항시 유효 (mixture)
    valid_width = np.sqrt(2 * data[:n].var() / n * (1 + 1/n) * np.log(2*np.sqrt(n+1)/0.05))
    valid_reject.append(abs(x_bar) > valid_width)

ax.plot(list(ns), np.cumsum(fixed_reject) / np.arange(1, len(ns)+1), label='Fixed (false positive rate)')
ax.set_xlabel('관측 수'); ax.set_ylabel('누적 기각 비율')
ax.set_title('연속 모니터링: 고정 vs 항시 유효')
ax.legend()
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 연속 모니터링과 항시 유효한 추론의 핵심 알고리즘을 직접 구현하세요.

# %%
# 연속 모니터링과 항시 유효한 추론 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 연속 모니터링과 항시 유효한 추론 방법론의 성능을 비교 분석하세요.

# %%
# 연속 모니터링과 항시 유효한 추론 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 연속 모니터링과 항시 유효한 추론을 적용하고 결과를 해석하세요.

# %%
# 연속 모니터링과 항시 유효한 추론 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
