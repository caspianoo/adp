# %% [markdown]
# # Ch06-05: GARCH와 변동성 모형

# %% [markdown]
# ## 학습 목표
#
# - GARCH와 변동성 모형 이론
# - GARCH와 변동성 모형 구현
# - GARCH와 변동성 모형 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# GARCH(1,1): $\sigma_t^2 = \omega + \alpha\epsilon_{t-1}^2 + \beta\sigma_{t-1}^2$. 조건: $\alpha + \beta < 1$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)
n = 1000; omega, alpha, beta = 0.1, 0.15, 0.8
sigma2, returns = np.zeros(n), np.zeros(n)
sigma2[0] = omega / (1 - alpha - beta)
for t in range(1, n):
    sigma2[t] = omega + alpha*returns[t-1]**2 + beta*sigma2[t-1]
    returns[t] = np.sqrt(sigma2[t]) * np.random.standard_t(5)
fig, axes = plt.subplots(2, 1, figsize=(14, 8))
axes[0].plot(returns); axes[0].set_title('수익률')
axes[1].plot(np.sqrt(sigma2)); axes[1].set_title('조건부 변동성')
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# GARCH와 변동성 모형의 핵심 알고리즘을 직접 구현하세요.

# %%
# GARCH와 변동성 모형 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 GARCH와 변동성 모형 방법론의 성능을 비교 분석하세요.

# %%
# GARCH와 변동성 모형 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 GARCH와 변동성 모형을 적용하고 결과를 해석하세요.

# %%
# GARCH와 변동성 모형 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
