# %% [markdown]
# # Ch03-06: 경험적 베이즈 방법

# %% [markdown]
# ## 학습 목표
#
# - 경험적 베이즈 방법의 핵심 이론 이해
# - 경험적 베이즈 방법의 실전 구현
# - 경험적 베이즈 방법 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# James-Stein: $\hat\mu_i^{JS} = \bar X + (1 - \frac{(p-2)s^2}{\sum(X_i-\bar X)^2})(X_i - \bar X)$. p≥3이면 MLE보다 MSE가 작습니다(Stein의 역설).

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 경험적 베이즈 방법 ===")

# James-Stein 추정
p = 10  # 차원
theta_true = np.random.normal(3, 1, p)
X = theta_true + np.random.normal(0, 1, p)

# MLE
theta_mle = X.copy()

# James-Stein
shrinkage = max(0, 1 - (p - 2) / np.sum(X**2))
theta_js = shrinkage * X

mse_mle = np.sum((theta_mle - theta_true)**2)
mse_js = np.sum((theta_js - theta_true)**2)
print(f"MLE MSE: {mse_mle:.4f}")
print(f"JS MSE: {mse_js:.4f}")
print(f"개선율: {(1 - mse_js/mse_mle)*100:.1f}%")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 경험적 베이즈 방법의 핵심 알고리즘을 직접 구현하세요.

# %%
# 경험적 베이즈 방법 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 경험적 베이즈 방법 방법론의 성능을 비교 분석하세요.

# %%
# 경험적 베이즈 방법 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 경험적 베이즈 방법을 적용하고 결과를 해석하세요.

# %%
# 경험적 베이즈 방법 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
