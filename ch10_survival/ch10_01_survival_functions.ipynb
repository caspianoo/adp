# %% [markdown]
# # Ch10-01: 생존 함수와 위험 함수

# %% [markdown]
# ## 학습 목표
#
# - 생존 함수와 위험 함수 이론
# - 생존 함수와 위험 함수 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $S(t) = P(T > t)$, $h(t) = \lim_{dt\to 0}\frac{P(t \leq T < t+dt|T \geq t)}{dt} = \frac{f(t)}{S(t)}$, $H(t) = -\log S(t)$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np, matplotlib.pyplot as plt
from scipy import stats
t = np.linspace(0.01, 10, 200)
dists = {'Exponential(0.5)': stats.expon(scale=2), 'Weibull(2,1)': stats.weibull_min(2), 'Lognormal(0,1)': stats.lognorm(1)}
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for ax, title in zip(axes, ['S(t)', 'h(t)', 'H(t)']):
    for name, d in dists.items():
        if title == 'S(t)': ax.plot(t, d.sf(t), label=name)
        elif title == 'h(t)': ax.plot(t, d.pdf(t)/d.sf(t), label=name)
        else: ax.plot(t, -np.log(d.sf(t)), label=name)
    ax.set_title(title); ax.legend(fontsize=8)
plt.tight_layout(); plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 생존 함수와 위험 함수의 핵심 알고리즘을 직접 구현하세요.

# %%
# 생존 함수와 위험 함수 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 생존 함수와 위험 함수 방법론의 성능을 비교 분석하세요.

# %%
# 생존 함수와 위험 함수 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 생존 함수와 위험 함수을 적용하고 결과를 해석하세요.

# %%
# 생존 함수와 위험 함수 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
