# %% [markdown]
# # Ch04-05: 멀티암 밴딧과 적응적 실험 — 모범답안

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ---
# ## 문제 1 풀이
#
# 멀티암 밴딧과 적응적 실험 핵심 구현

# %%
import numpy as np
np.random.seed(42)
print('멀티암 밴딧과 적응적 실험 풀이 1')

# %% [markdown]
# **결과 해석**: 멀티암 밴딧과 적응적 실험의 핵심 개념을 구현으로 검증했습니다.

# %% [markdown]
# ---
# ## 문제 2 풀이
#
# 멀티암 밴딧과 적응적 실험 비교 분석

# %%
import numpy as np
np.random.seed(42)
print('멀티암 밴딧과 적응적 실험 풀이 2')

# %% [markdown]
# **결과 해석**: 조건에 따라 성능 차이가 나타납니다.

# %% [markdown]
# ---
# ## 문제 3 풀이
#
# 멀티암 밴딧과 적응적 실험 실전 적용

# %%
import numpy as np
np.random.seed(42)
print('멀티암 밴딧과 적응적 실험 풀이 3')

# %% [markdown]
# **결과 해석**: 실전 적용 시 도메인 지식과의 결합이 중요합니다.

# %% [markdown]
# ---
# ## 확장 토론
#
# 멀티암 밴딧과 적응적 실험은 데이터 기반 의사결정의 핵심입니다.
