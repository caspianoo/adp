# %% [markdown]
# # Ch05-03: 분위수 회귀

# %% [markdown]
# ## 학습 목표
#
# - 분위수 회귀 이론
# - 분위수 회귀 구현
# - 분위수 회귀 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $\min_\beta \sum_{i=1}^n \rho_\tau(y_i - x_i^T\beta)$, $\rho_\tau(u) = u(\tau - I(u<0))$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
import statsmodels.api as sm

np.random.seed(42)
n = 500
X = np.random.uniform(0, 10, n)
Y = 2 + 0.5*X + (0.5 + 0.3*X) * np.random.standard_t(5, n)  # 이분산

X_const = sm.add_constant(X)
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(X, Y, alpha=0.3, s=10)
for q in [0.1, 0.25, 0.5, 0.75, 0.9]:
    model = sm.QuantReg(Y, X_const).fit(q=q)
    x_plot = np.linspace(0, 10, 100)
    ax.plot(x_plot, model.params[0] + model.params[1]*x_plot, label=f'τ={q}')
ax.legend(); ax.set_title('분위수 회귀')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 분위수 회귀의 핵심 알고리즘을 직접 구현하세요.

# %%
# 분위수 회귀 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 분위수 회귀 방법론의 성능을 비교 분석하세요.

# %%
# 분위수 회귀 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 분위수 회귀을 적용하고 결과를 해석하세요.

# %%
# 분위수 회귀 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
