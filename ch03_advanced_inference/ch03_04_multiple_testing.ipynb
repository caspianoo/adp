# %% [markdown]
# # Ch03-04: 다중 검정과 FDR 제어

# %% [markdown]
# ## 학습 목표
#
# - 다중 검정과 FDR 제어의 핵심 이론 이해
# - 다중 검정과 FDR 제어의 실전 구현
# - 다중 검정과 FDR 제어 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# FWER: $P(\text{any false rejection}) \leq \alpha$. Bonferroni: $\alpha_i = \alpha/m$. BH: $p_{(i)} \leq \frac{i}{m}q$ → FDR $\leq q$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 다중 검정과 FDR 제어 ===")

# 다중 검정 시뮬레이션
m = 1000  # 검정 수
m0 = 900  # 참 귀무가설 수
np.random.seed(42)

# p-value 생성
p_null = np.random.uniform(0, 1, m0)  # H0 참
p_alt = np.random.beta(0.5, 5, m - m0)  # H1 참
p_values = np.concatenate([p_null, p_alt])
true_labels = np.array([0]*m0 + [1]*(m-m0))

# Bonferroni
reject_bonf = p_values < 0.05/m

# BH (Benjamini-Hochberg)
from scipy.stats import rankdata
ranks = rankdata(p_values)
bh_threshold = ranks / m * 0.05
sorted_idx = np.argsort(p_values)
bh_reject = np.zeros(m, dtype=bool)
for i in sorted_idx[::-1]:
    if p_values[i] <= bh_threshold[i]:
        bh_reject[sorted_idx[:int(ranks[i])]] = True
        break

print(f"Bonferroni: {reject_bonf.sum()} rejections, FDR={reject_bonf[true_labels==0].mean():.3f}")
print(f"BH: {bh_reject.sum()} rejections, FDR={bh_reject[true_labels==0].mean():.3f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 다중 검정과 FDR 제어의 핵심 알고리즘을 직접 구현하세요.

# %%
# 다중 검정과 FDR 제어 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 다중 검정과 FDR 제어 방법론의 성능을 비교 분석하세요.

# %%
# 다중 검정과 FDR 제어 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 다중 검정과 FDR 제어을 적용하고 결과를 해석하세요.

# %%
# 다중 검정과 FDR 제어 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
