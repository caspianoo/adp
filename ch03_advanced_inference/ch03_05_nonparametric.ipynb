# %% [markdown]
# # Ch03-05: 비모수 검정 심화

# %% [markdown]
# ## 학습 목표
#
# - 비모수 검정 심화의 핵심 이론 이해
# - 비모수 검정 심화의 실전 구현
# - 비모수 검정 심화 방법론 비교

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# Wilcoxon: 순위 기반 검정. KS: $D_n = \sup_x |F_n(x) - F(x)|$, $\sqrt{n}D_n \xrightarrow{d} K$ (Kolmogorov 분포). KDE: $\hat{f}(x) = \frac{1}{nh}\sum K(\frac{x-X_i}{h})$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
print("=== 비모수 검정 심화 ===")

# KS 검정과 커널 밀도 추정
data = np.random.exponential(2, 100)

# KS 검정: 정규성 검정
ks_stat, ks_p = stats.kstest(data, 'norm', args=(data.mean(), data.std()))
print(f"KS 검정 (정규): stat={ks_stat:.4f}, p={ks_p:.4f}")

ks_stat2, ks_p2 = stats.kstest(data, 'expon', args=(0, data.mean()))
print(f"KS 검정 (지수): stat={ks_stat2:.4f}, p={ks_p2:.4f}")

# KDE with different bandwidths
x_grid = np.linspace(-1, 15, 200)
fig, ax = plt.subplots(figsize=(10, 6))
ax.hist(data, bins=20, density=True, alpha=0.3, label='히스토그램')
for bw in [0.3, 0.7, 1.5]:
    kde = stats.gaussian_kde(data, bw_method=bw)
    ax.plot(x_grid, kde(x_grid), label=f'KDE h={bw}')
ax.plot(x_grid, stats.expon.pdf(x_grid, scale=2), 'k--', label='참 분포')
ax.legend(); ax.set_title('커널 밀도 추정')
plt.show()

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 비모수 검정 심화의 핵심 알고리즘을 직접 구현하세요.

# %%
# 비모수 검정 심화 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 비모수 검정 심화 방법론의 성능을 비교 분석하세요.

# %%
# 비모수 검정 심화 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 비모수 검정 심화을 적용하고 결과를 해석하세요.

# %%
# 비모수 검정 심화 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - Casella & Berger (2002)
# - Wasserman (2004). 'All of Statistics'
