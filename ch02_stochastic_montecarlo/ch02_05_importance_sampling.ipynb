# %% [markdown]
# # Ch02-05: 중요도 샘플링

# %% [markdown]
# ## 학습 목표
#
# - 최적 제안 분포의 이론
# - 자체 정규화와 유효 표본 크기
# - 희귀 사건 시뮬레이션

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# $E_p[f(X)] = E_q[f(X) \frac{p(X)}{q(X)}]$, 가중치 $w(x) = p(x)/q(x)$
# 최적 제안: $q^*(x) \propto |f(x)|p(x)$
# 유효 표본 크기: $ESS = \frac{(\sum w_i)^2}{\sum w_i^2}$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
np.random.seed(42)

# 중요도 샘플링 기본 구현
print("=== 중요도 샘플링 ===")

# 중요도 샘플링: P(X > 4) where X ~ N(0,1)
N = 100000
# 직접 MC
x_direct = np.random.normal(0, 1, N)
p_direct = (x_direct > 4).mean()

# IS with shifted normal q = N(4, 1)
x_is = np.random.normal(4, 1, N)
from scipy.stats import norm
w = norm.pdf(x_is, 0, 1) / norm.pdf(x_is, 4, 1)
p_is = (w * (x_is > 4)).mean()

p_true = 1 - norm.cdf(4)
print(f"참값: {p_true:.8f}")
print(f"직접 MC: {p_direct:.8f} (상대오차: {abs(p_direct-p_true)/p_true:.2%})")
print(f"IS: {p_is:.8f} (상대오차: {abs(p_is-p_true)/p_true:.2%})")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 중요도 샘플링의 핵심 알고리즘을 직접 구현하세요.

# %%
# 중요도 샘플링 구현
import numpy as np
np.random.seed(42)

# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 중요도 샘플링에서 다양한 하이퍼파라미터/조건에 따른 성능을 비교 분석하세요.

# %%
# 중요도 샘플링 파라미터 분석
# TODO: 체계적 비교

# %% [markdown]
# ### 문제 3 [★★★]
#
# 중요도 샘플링을 실전 문제에 적용하고 결과를 해석하세요.

# %%
# 중요도 샘플링 실전 적용
# TODO: 실제 데이터/문제에 적용

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 및 논문 참조
