# %% [markdown]
# # Ch06-02: ARIMA/SARIMA 모델링

# %% [markdown]
# ## 학습 목표
#
# - ARIMA/SARIMA 모델링 이론
# - ARIMA/SARIMA 모델링 구현
# - ARIMA/SARIMA 모델링 해석

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# ARIMA(p,d,q): $\phi(B)(1-B)^d X_t = \theta(B)\epsilon_t$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

np.random.seed(42)
n = 300
e = np.random.normal(0, 1, n+2)
y = np.zeros(n)
for t in range(2, n): y[t] = 0.6*y[t-1] - 0.3*y[t-2] + e[t] + 0.4*e[t-1]

model = ARIMA(y, order=(2, 0, 1)).fit()
print(model.summary().tables[1])

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# ARIMA/SARIMA 모델링의 핵심 알고리즘을 직접 구현하세요.

# %%
# ARIMA/SARIMA 모델링 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 ARIMA/SARIMA 모델링 방법론의 성능을 비교 분석하세요.

# %%
# ARIMA/SARIMA 모델링 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 ARIMA/SARIMA 모델링을 적용하고 결과를 해석하세요.

# %%
# ARIMA/SARIMA 모델링 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
