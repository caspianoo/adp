# %% [markdown]
# # Ch11-01: 볼록 최적화와 KKT

# %% [markdown]
# ## 학습 목표
#
# - 볼록 최적화와 KKT 이론
# - 볼록 최적화와 KKT 구현

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12
np.random.seed(42)

# %% [markdown]
# ## 이론적 배경
#
# KKT: $\nabla f + \sum \lambda_i \nabla g_i + \sum \nu_j \nabla h_j = 0$, $\lambda_i \geq 0$, $\lambda_i g_i = 0$

# %% [markdown]
# ## 구현 가이드

# %%
import numpy as np, matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)

import numpy as np, matplotlib.pyplot as plt
from scipy.optimize import minimize
# 2D 볼록 최적화
def f(x): return (x[0]-1)**2 + (x[1]-2)**2
def g(x): return x[0] + x[1] - 1  # 부등식 g <= 0
result = minimize(f, [0, 0], constraints={'type': 'ineq', 'fun': lambda x: -g(x)})
print(f"최적해: {result.x.round(4)}, f*: {result.fun:.4f}")

# %% [markdown]
# ---
# ## 연습 문제

# %% [markdown]
# ### 문제 1 [★]
#
# 볼록 최적화와 KKT의 핵심 알고리즘을 직접 구현하세요.

# %%
# 볼록 최적화와 KKT 구현
import numpy as np
np.random.seed(42)
# TODO: 핵심 알고리즘 구현

# %% [markdown]
# ### 문제 2 [★★]
#
# 다양한 조건에서 볼록 최적화와 KKT 방법론의 성능을 비교 분석하세요.

# %%
# 볼록 최적화와 KKT 벤치마크
# TODO: 체계적 비교 실험 설계

# %% [markdown]
# ### 문제 3 [★★★]
#
# 실제 데이터에 볼록 최적화와 KKT을 적용하고 결과를 해석하세요.

# %%
# 볼록 최적화와 KKT 실전 적용
# TODO: 실전 문제 적용 및 해석

# %% [markdown]
# ---
# ## 참고 자료
#
# - 관련 교재 참조
